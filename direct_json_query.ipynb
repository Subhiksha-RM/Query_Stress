# %% [markdown]
# # Direct Queries on JSON -- 100 timestamps

# %%
# Total revenue by node type 
def total_revenue_by_node_type(data):
    revenue_by_type = {}
    for node in data['nodes']:
        if 'revenue' in node:
            node_type = node['node_type']
            revenue_by_type[node_type] = revenue_by_type.get(node_type, 0) + node['revenue']
    return revenue_by_type

# %%
# Average revenue of business units
def average_revenue_business_units(data):
    total_revenue = 0
    count = 0
    for node in data['nodes']:
        if node['node_type'] == 'BusinessUnit':
            total_revenue += node['revenue']
            count += 1
    return total_revenue / count if count > 0 else 0

# %%
#cost of product offerings total
def total_cost_of_product_offerings(data):
    total_cost = 0
    for node in data['nodes']:
        if node['node_type'] == 'ProductOffering':
            total_cost += node['cost']
    return total_cost

# %%
# Facitlity utilization
def facility_utilization(data):
    utilization = {}
    for node in data['nodes']:
        if node['node_type'] == 'Facility':
            utilization[node['name']] = (node['current_capacity'] / node['max_capacity']) * 100
    return utilization

# %%
# Supplier Reliability
def supplier_reliability(data):
    suppliers = []
    for node in data['nodes']:
        if node['node_type'] == 'Supplier':
            suppliers.append((node['name'], node['reliability']))
    suppliers.sort(key=lambda x: x[1], reverse=True)
    return suppliers

# %%
# parts expiry
def parts_nearing_expiry(data, threshold):
    parts_near_expiry = []
    for node in data['nodes']:
        if node['node_type'] == 'Parts' and node['expiry'] <= threshold:
            parts_near_expiry.append(node['name'])
    return parts_near_expiry

# %%
#Average demand for product offerings
def average_demand_for_product_offerings(data):
    total_demand = 0
    count = 0
    for node in data['nodes']:
        if node['node_type'] == 'ProductOffering':
            total_demand += node['demand']
            count += 1
    return total_demand / count if count > 0 else 0

# %%
# Edge cost / link cost 
def relationship_costs(data):
    total_transportation_cost = 0
    total_storage_cost = 0
    for link in data['links']:
        if link['relationship_type'] == 'SupplierToWarehouse':
            total_transportation_cost += link['transportation_cost']
        elif link['relationship_type'] == 'WarehouseToParts':
            total_storage_cost += link['storage_cost']
    return total_transportation_cost, total_storage_cost

# %%
#nodes created after a certain timestamp 
def nodes_created_after(data, timestamp):
    recent_nodes = []
    for node in data['nodes']:
        if node['created_at'] > timestamp:
            recent_nodes.append(node)
    return recent_nodes

# %%
#warehouse safety stock levels
def safety_stock_levels_in_warehouses(data):
    safety_stock_levels = {}
    for node in data['nodes']:
        if node['node_type'] == 'Warehouse':
            safety_stock_levels[node['name']] = node['safety_stock']
    return safety_stock_levels

# %%
# total operating cost of facilities
def total_operating_cost_of_facilities(data):
    total_cost = 0
    for node in data['nodes']:
        if node['node_type'] == 'Facility':
            total_cost += node['operating_cost']
    return total_cost

# %%
# total revenue by business unit
def total_revenue_by_business_unit(data):
    revenue_by_unit = {}
    for node in data['nodes']:
        if node['node_type'] == 'BusinessUnit':
            revenue_by_unit[node['name']] = node['revenue']
    return revenue_by_unit

# %%
import json
import os

def process_json_files(input_folder):
    results = []
    for filename in os.listdir(input_folder):
        if filename.endswith(".json"):
            with open(os.path.join(input_folder, filename), 'r') as f:
                data = json.load(f)
                result = total_revenue_by_business_unit(data)
                results.append(result)
    return results

 822.04}, {'VSyZxTaT': 144.35, 'eyDMMfWA': 840.82, 'yYxtoNqH': 822.04}, {'VSyZxTaT': 144.35, 'eyDMMfWA': 840.82, 'YssHaaNe': 822.04}, {'VSyZxTaT': 144.35, 'eyDMMfWA': 840.82, 'zJeVgOOi': 822.04}, {'VSyZxTaT': 144.35, 'eyDMMfWA': 840.82, 'zJeVgOOi': 822.04}, {'YbdbTWFN': 468.51, 'CrkocJcW': 186.06, 'hZMPzrIA': 49.13}, {'VSyZxTaT': 144.35, 'eyDMMfWA': 305.36, 'zJeVgOOi': 822.04}, {'VSyZxTaT': 144.35, 'eyDMMfWA': 305.36, 'zJeVgOOi': 822.04}, {'VSyZxTaT': 144.35, 'eyDMMfWA': 305.36, 'zJeVgOOi': 223.58}, {'VSyZxTaT': 144.35, 'noEDwHUW': 897.84, 'zJeVgOOi': 223.58}, {'VSyZxTaT': 144.35, 'noEDwHUW': 897.84, 'zJeVgOOi': 223.58}, {'VSyZxTaT': 144.35, 'noEDwHUW': 897.84, 'etsVsiGj': 100.19}, {'VSyZxTaT': 144.35, 'noEDwHUW': 897.84, 'etsVsiGj': 100.19}, {'VSyZxTaT': 144.35, 'mwdKltLH': 200.52, 'etsVsiGj': 100.19}, {'VSyZxTaT': 144.35 ...

# %%
import json
import os
from functools import lru_cache
from datetime import datetime, timedelta
import psutil
import time

def memory_usage():
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / (1024 ** 2)  # bytes to MB conversion

start_time = time.time()
start_memory = memory_usage()

@lru_cache(maxsize=None)
def load_json_file(file_path):
    with open(file_path, 'r') as f:
        return json.load(f)

# Previously mentioned functions
def total_revenue_by_business_unit(data):
    revenue_by_unit = {}
    for node in data['nodes']:
        if node['node_type'] == 'BusinessUnit':
            revenue_by_unit[node['name']] = node['revenue']
    return revenue_by_unit

def total_cost_of_product_offerings(data):
    total_cost = 0
    for node in data['nodes']:
        if node['node_type'] == 'ProductOffering':
            total_cost += node['cost']
    return total_cost

def facility_utilization(data):
    utilization = {}
    for node in data['nodes']:
        if node['node_type'] == 'Facility':
            utilization[node['name']] = (node['max_capacity'])
    return utilization

def supplier_reliability(data):
    suppliers = []
    for node in data['nodes']:
        if node['node_type'] == 'Supplier':
            suppliers.append((node['name'], node['reliability']))
    suppliers.sort(key=lambda x: x[1], reverse=True)
    return suppliers

def parts_nearing_expiry(data, threshold):
    parts_near_expiry = []
    for node in data['nodes']:
        if node['node_type'] == 'Parts' and node['expiry'] <= threshold:
            parts_near_expiry.append(node['name'])
    return parts_near_expiry

def average_demand_for_product_offerings(data):
    total_demand = 0
    count = 0
    for node in data['nodes']:
        if node['node_type'] == 'ProductOffering':
            total_demand += node['demand']
            count += 1
    return total_demand / count if count > 0 else 0

def total_operating_cost_of_facilities(data):
    total_cost = 0
    for node in data['nodes']:
        if node['node_type'] == 'Facility':
            total_cost += node['operating_cost']
    return total_cost

def safety_stock_levels_in_warehouses(data):
    safety_stock_levels = {}
    for node in data['nodes']:
        if node['node_type'] == 'Warehouse':
            safety_stock_levels[node['name']] = node['safety_stock']
    return safety_stock_levels

def relationship_costs(data):
    total_transportation_cost = 0
    total_storage_cost = 0
    for link in data['links']:
        if link['relationship_type'] == 'SupplierToWarehouse':
            total_transportation_cost += link['transportation_cost']
        elif link['relationship_type'] == 'WarehouseToParts':
            total_storage_cost += link['storage_cost']
    return total_transportation_cost, total_storage_cost

def nodes_created_after(data, timestamp):
    recent_nodes = []
    for node in data['nodes']:
        if node['created_at'] > timestamp:
            recent_nodes.append(node)
    return recent_nodes

# Example usage
folder_path = 'C:/Users/HP/LAM_VS/query_stress/dc_stat_100_large'

# Process each JSON file and apply the functions
for file_name in os.listdir(folder_path):
    if file_name.endswith('.json'):
        file_path = os.path.join(folder_path, file_name)
        data = load_json_file(file_path)
        
        # Apply the functions
        revenue_by_unit = total_revenue_by_business_unit(data)
        total_cost = total_cost_of_product_offerings(data)
        utilization = facility_utilization(data)
        reliability = supplier_reliability(data)
        parts_expiry = parts_nearing_expiry(data, threshold=30)
        avg_demand = average_demand_for_product_offerings(data)
        operating_cost = total_operating_cost_of_facilities(data)
        safety_stock = safety_stock_levels_in_warehouses(data)
        transport_cost, storage_cost = relationship_costs(data)
        recent_nodes = nodes_created_after(data, timestamp=0)

        # Print or store the results as needed
        print(f"Results for {file_name}:")
        print(f"Revenue by Business Unit: {revenue_by_unit}")
        print(f"Total Cost of Product Offerings: {total_cost}")
        print(f"Facility Utilization: {utilization}")
        print(f"Supplier Reliability: {reliability}")
        print(f"Parts Nearing Expiry: {parts_expiry}")
        print(f"Average Demand for Product Offerings: {avg_demand}")
        print(f"Total Operating Cost of Facilities: {operating_cost}")
        print(f"Safety Stock Levels in Warehouses: {safety_stock}")
        print(f"Relationship Costs: Transportation - {transport_cost}, Storage - {storage_cost}")
        print(f"Nodes Created After Timestamp: {recent_nodes}")

end_time = time.time()
end_memory = memory_usage()

print(f"Time taken: {end_time - start_time} seconds")
print(f"Memory used: {end_memory - start_memory} MB")
# Out:
# Results for 1.json:
# Revenue by Business Unit: {'cGeOyTgI': 468.51, 'RVVIAToD': 784.19, 'hZMPzrIA': 727.69}
# Total Cost of Product Offerings: 4746.150000000001
# Facility Utilization: {'vdTkFiIn': 82, 'bBzjgTay': 9, 'egQMaRqe': 74, 'vVSuldYi': 26, 'bVKWPKcV': 29, 'nxLQmvAQ': 48, 'DUBEirbR': 40, 'gEVLdKwA': 33, 'kwBNCAUp': 62, 'cYxJYjPe': 25, 'tLgtoBiM': 14, 'aePRdVyh': 6, 'vNDDpWge': 29, 'oXzmjPSW': 39, 'XaBJDgIW': 98, 'fUTqqcmA': 70, 'MlUbawCs': 43, 'QkguXeuz': 51, 'MIBkvcne': 89, 'xkRbHPVZ': 74, 'JvBOKLxk': 66, 'TloxfXMr': 80, 'KoUNFcHc': 47, 'jfQOAaSM': 3}
# Supplier Reliability: [('mBDYhRUe', 992.95), ('fueIsZkc', 990.85), ('HCXvstLl', 972.4), ('wXvvMILL', 968.13), ('kyavilmB', 959.21), ('SWHzXxPD', 955.29), ('MvtJOGdi', 954.44), ('xEjyDNqh', 951.68), ('GqKIGLAA', 950.49), ('IRUbBuQk', 917.6), ('OjSWxZkP', 907.93), ('EBcWZVEX', 905.0), ('uPBrfTGk', 891.52), ('ZXhHBKop', 869.36), ('oFxYzTQW', 868.18), ('ibBzRKvH', 864.46), ('qgIiTrDH', 850.06), ('uuoheTXr', 840.12), ('NGjDaYVZ', 831.62), ('oIxwOrMK', 807.21), ('FuPYBvTP', 801.13), ('oYTHYjgI', 794.71), ('xVBbpeqO', 781.76), ('msrZeITP', 772.96), ('UKRIJhuX', 751.1), ('hptsISDN', 750.6), ('fxyBdhfx', 749.1), ('BwpiFPRP', 737.83), ('rwIhCkHV', 733.24), ('eJTWmoxo', 727.34), ('XgQVgVhM', 690.24), ('rccRPnLW', 686.26), ('QJybIRve', 683.81), ('gWarQGpU', 677.39), ('IxgvseUC', 669.68), ('EXSvCSjf', 656.21), ('lsqoJfaB', 645.52), ('VTbAhENr', 638.17), ('FORCwgEm', 617.05), ('NUUIkHeO', 612.6), ('INphtuSR', 598.98), ('oRBjbfjs', 578.97), ('oNplGQJZ', 577.39), ('CqRIAGAX', 564.19), ('qKmlQjfl', 556.48), ('SuGKLEqb', 554.39), ('IWCMdagu', 553.25), ('YvuVjZTS', 505.8), ('PvrRmTNY', 492.84), ('AkeuISed', 485.37), ('WKhRGLBd', 481.76), ('mxIEYanm', 462.38), ('LJhuemeN', 461.41), ('tqbnlxRi', 448.46), ('JLTrRict', 429.94), ('oiTydaWU', 424.69), ('IlAfsaOw', 422.8), ('IIpeZcvf', 401.17), ('gyyNoFOp', 379.32), ('WbwosCUk', 372.33), ('tGRHwQDg', 371.28), ('hmqBuMxt', 357.17), ('sgYRaUsd', 355.26), ('NEYJEXuO', 353.71), ('mVDuZyxx', 352.63), ('LXZnpOIZ', 351.04), ('ASxvNODQ', 346.32), ('tCtmIRRR', 335.81), ('LpeSpdCl', 330.43), ('SzUCaQjS', 330.41), ('CJshkOVJ', 317.43), ('oydwHkto', 315.35), ('QdeHzqWs', 310.23), ('OlzYWvzC', 303.94), ('ydMdYXlZ', 301.14), ('WWfkiorT', 266.45), ('JDwrxaAD', 263.46), ('FkejbOtI', 257.86), ('fyCYjFNX', 255.88), ('LojhkQGn', 251.15), ('nliFSzin', 239.15), ('pYUPDEOo', 219.99), ('kbFJZptm', 207.02), ('jYArdIik', 204.44), ('xekDXkqP', 202.88), ('ByRaQhxV', 180.73), ('bwZZSEFG', 172.78), ('fJVRuMDh', 139.46), ('YInIpBcB', 129.31), ('KsTpCCCl', 124.95), ('sXRKXSNK', 122.58), ('VHkehmdq', 81.29), ('gofQqFCS', 79.86), ('wDsmrfEo', 71.99), ('rChEXGly', 70.37), ('fuHchKVj', 31.75), ('tuLJwjOU', 23.61), ('QNcmTOWr', 16.82), ('LqjTKKjM', 13.5), ('qQpWHRZc', 8.32)]
# Parts Nearing Expiry: ['ygsRsQcu', 'AfsvQsvS', 'VlVtRTNM', 'WjTrWyRX', 'nsLgYdJU', 'GPvowryr', 'GzocVWAA', 'kUjTArxo', 'umxwvkyh', 'onLlVkVt', 'rbVlqUAA', 'oMgwwWuK', 'MMHCcxts']
# Average Demand for Product Offerings: 50.75
# Total Operating Cost of Facilities: 11016.29
# Safety Stock Levels in Warehouses: {'eWchZYRX': 65, 'IiwAGNSn': 77, 'vWCkUCQm': 11, 'yTiAZsDi': 8, 'iNcMvIVA': 81, 'vJpOqyeC': 70, 'wxvqmwqT': 18, 'SWUFfMZs': 74, 'lsXnhHdH': 37, 'pSWYIzXa': 25, 'vgHNfewY': 36, 'JRZvwomO': 9, 'JigUivKh': 77, 'HDKTRhTB': 96, 'EKhUatdS': 40, 'KPvoqhFd': 77, 'izkuayyI': 80, 'wwVFELoF': 72, 'CRWsHVzw': 15, 'hFHXNsCU': 46, 'PGfHaPZa': 71, 'LDXFmTRI': 96, 'YVgbJLSQ': 86, 'kgKtWSWC': 67, 'mHyyGadG': 16, 'uGQAiaBo': 92, 'DHyPKhMa': 5, 'VjjATpac': 73, 'QQoxDPdM': 59, 'iOnHNywh': 84, 'gBKpmXxD': 15, 'BPGIWpYC': 44, 'bifliefn': 93, 'aWHmDNrx': 68, 'IxRTeKJB': 88, 'dCIkcCWQ': 99, 'YXarmeNj': 48, 'UgnXnRac': 84, 'cpyNAMuv': 69, 'GZshKMTK': 68, 'FcqRMWIn': 49, 'PtzHvAAQ': 15, 'eOSUmSxC': 50, 'HshRmseY': 58, 'ptTncHvq': 50, 'FEGGwrsi': 31, 'kXiPYyAv': 55, 'qTMvFCXQ': 53, 'pBLEjLXO': 24, 'mYSfVLit': 100, 'zxXYzuAt': 85, 'HTyXEoAY': 53, 'tBkAvFoZ': 32, 'hrKwABOW': 41, 'PcRPdsku': 31, 'NyPDKpZW': 57, 'raEsSsfI': 79, 'GHRtKwCq': 45, 'JApXpVmN': 86, 'HuVPVSNi': 53, 'HLUdfHgA': 58, 'apVYLvVs': 17, 'etsvDcAY': 50, 'BrNLfQGk': 30, 'vagZOBDr': 61, 'EmptHziW': 39, 'YoDyVGjG': 48, 'cfWBRNMO': 59, 'NSXRZsqG': 72, 'DnOcjrxB': 9, 'YgkiRlJk': 12, 'mFGHLgRV': 41, 'jUTQzrEE': 82, 'RzaZnyYc': 1, 'zKQbUatA': 98, 'iPfMrTIF': 97, 'JmrWHfoM': 59, 'TMHsmiKm': 50, 'eJEJGQWP': 60, 'vbcVzAYh': 55, 'LFBdCwPE': 66, 'ctjZJaan': 43, 'miNQMuUH': 33, 'xTzfppVO': 53, 'YnzkZPGH': 32, 'lHafErqM': 93, 'jmLTUkah': 5, 'KSDuhtOQ': 9, 'wmbwcLom': 46, 'CztccWcP': 21, 'duJxKXHO': 84, 'JpRPIbCV': 70, 'oQqSUiNj': 34, 'rxhabTjS': 81, 'AlwqnFZA': 99, 'GDeVCOAe': 73, 'fqbayTdQ': 49, 'cDpHSwfg': 95, 'kgmWFwHw': 55, 'EQipZnEE': 53}
# Relationship Costs: Transportation - 98705.36000000009, Storage - 101421.72999999995
# Nodes Created After Timestamp: []
# Results for 10.json:
# Revenue by Business Unit: {'YbdbTWFN': 468.51, 'CrkocJcW': 186.06, 'uhTkgszG': 29.91}
# Total Cost of Product Offerings: 3773.5600000000004
# Facility Utilization: {'vdTkFiIn': 82, 'bBzjgTay': 9, 'egQMaRqe': 10, 'vVSuldYi': 26, 'zbYQkDOz': 29, 'gWdjApIt': 48, 'DUBEirbR': 42, 'gEVLdKwA': 33, 'kwBNCAUp': 62, 'cYxJYjPe': 25, 'tLgtoBiM': 14, 'aePRdVyh': 6, 'vNDDpWge': 29, 'oXzmjPSW': 20, 'XaBJDgIW': 98, 'kshZRZFD': 56, 'MlUbawCs': 43, 'QkguXeuz': 51, 'MIBkvcne': 89, 'xkRbHPVZ': 74, 'JvBOKLxk': 66, 'TloxfXMr': 80, 'KoUNFcHc': 47, 'CwWgxpoE': 3}
# Supplier Reliability: [('mBDYhRUe', 992.95), ('fueIsZkc', 990.85), ('HCXvstLl', 972.4), ('oLIAZrge', 968.13), ('kyavilmB', 959.21), ('SWHzXxPD', 955.29), ('MvtJOGdi', 954.44), ('xEjyDNqh', 951.68), ('GqKIGLAA', 950.49), ('oGoHWqPy', 917.6), ('OjSWxZkP', 907.93), ('EBcWZVEX', 905.0), ('uPBrfTGk', 891.52), ('ZXhHBKop', 869.36), ('oFxYzTQW', 868.18), ('ibBzRKvH', 864.46), ('qgIiTrDH', 850.06), ('uuoheTXr', 840.12), ('NGjDaYVZ', 831.62), ('oIxwOrMK', 807.21), ('FuPYBvTP', 801.13), ('xVBbpeqO', 781.76), ('msrZeITP', 772.96), ('UKRIJhuX', 751.1), ('hptsISDN', 750.6), ('fxyBdhfx', 749.1), ('BwpiFPRP', 737.83), ('rwIhCkHV', 733.24), ('KauYdcnH', 727.34), ('XgQVgVhM', 690.24), ('rccRPnLW', 686.26), ('xXsoTdar', 685.7), ('QJybIRve', 683.81), ('gWarQGpU', 677.39), ('EXSvCSjf', 656.21), ('lsqoJfaB', 645.52), ('VTbAhENr', 638.17), ('NUUIkHeO', 612.6), ('INphtuSR', 598.98), ('lbIyQHlG', 579.23), ('oRBjbfjs', 578.97), ('oNplGQJZ', 577.39), ('CqRIAGAX', 564.19), ('qKmlQjfl', 556.48), ('SuGKLEqb', 554.39), ('IWCMdagu', 553.25), ('YvuVjZTS', 505.8), ('PvrRmTNY', 492.84), ('AkeuISed', 485.37), ('WKhRGLBd', 481.76), ('mxIEYanm', 462.38), ('LJhuemeN', 461.41), ('tqbnlxRi', 448.46), ('JLTrRict', 429.94), ('oiTydaWU', 424.69), ('IlAfsaOw', 422.8), ('kbFJZptm', 412.04), ('IIpeZcvf', 401.17), ('gyyNoFOp', 379.32), ('WbwosCUk', 372.33), ('tGRHwQDg', 371.28), ('hmqBuMxt', 357.17), ('sgYRaUsd', 355.26), ('NEYJEXuO', 353.71), ('mVDuZyxx', 352.63), ('LXZnpOIZ', 351.04), ('ASxvNODQ', 346.32), ('LpeSpdCl', 330.43), ('SzUCaQjS', 330.41), ('CJshkOVJ', 317.43), ('oydwHkto', 315.35), ('QdeHzqWs', 310.23), ('OlzYWvzC', 303.94), ('ydMdYXlZ', 301.14), ('IxgvseUC', 271.78), ('WWfkiorT', 266.45), ('oYTHYjgI', 265.97), ('JDwrxaAD', 263.46), ('FkejbOtI', 257.86), ('fyCYjFNX', 255.88), ('nliFSzin', 239.15), ('pYUPDEOo', 219.99), ('jYArdIik', 204.44), ('xekDXkqP', 202.88), ('ByRaQhxV', 180.73), ('bwZZSEFG', 172.78), ('fJVRuMDh', 139.46), ('YInIpBcB', 129.31), ('KsTpCCCl', 124.95), ('sXRKXSNK', 89.34), ('VHkehmdq', 81.29), ('gofQqFCS', 79.86), ('wDsmrfEo', 71.99), ('rChEXGly', 70.37), ('fuHchKVj', 31.75), ('tuLJwjOU', 23.61), ('QNcmTOWr', 16.82), ('LqjTKKjM', 13.5), ('keRmzshc', 11.9), ('qQpWHRZc', 8.32)]
# Parts Nearing Expiry: ['ygsRsQcu', 'AfsvQsvS', 'uDlTiStl', 'WjTrWyRX', 'nsLgYdJU', 'GPvowryr', 'GzocVWAA', 'umxwvkyh', 'CzRuwvIU', 'onLlVkVt', 'rbVlqUAA', 'oMgwwWuK', 'MMHCcxts']
# Average Demand for Product Offerings: 46.416666666666664
# Total Operating Cost of Facilities: 11739.380000000001
# Safety Stock Levels in Warehouses: {'eWchZYRX': 65, 'IiwAGNSn': 77, 'vWCkUCQm': 11, 'yTiAZsDi': 8, 'iNcMvIVA': 81, 'vJpOqyeC': 70, 'wxvqmwqT': 18, 'SWUFfMZs': 74, 'lsXnhHdH': 37, 'pSWYIzXa': 25, 'vgHNfewY': 36, 'JRZvwomO': 9, 'JigUivKh': 77, 'HDKTRhTB': 96, 'EKhUatdS': 40, 'mSojwEoo': 77, 'izkuayyI': 80, 'wwVFELoF': 72, 'CRWsHVzw': 15, 'hFHXNsCU': 46, 'PGfHaPZa': 71, 'LDXFmTRI': 96, 'YVgbJLSQ': 86, 'kgKtWSWC': 67, 'mHyyGadG': 16, 'uGQAiaBo': 92, 'DHyPKhMa': 5, 'VjjATpac': 73, 'QQoxDPdM': 59, 'iOnHNywh': 84, 'gBKpmXxD': 15, 'BPGIWpYC': 44, 'bifliefn': 93, 'aWHmDNrx': 68, 'IxRTeKJB': 88, 'dCIkcCWQ': 99, 'YXarmeNj': 48, 'WRGvDFLP': 82, 'cpyNAMuv': 69, 'GZshKMTK': 68, 'FcqRMWIn': 49, 'PtzHvAAQ': 15, 'eOSUmSxC': 50, 'HshRmseY': 58, 'ptTncHvq': 50, 'FEGGwrsi': 31, 'kXiPYyAv': 55, 'qTMvFCXQ': 53, 'pBLEjLXO': 24, 'mYSfVLit': 100, 'zxXYzuAt': 85, 'HTyXEoAY': 53, 'tBkAvFoZ': 32, 'hrKwABOW': 41, 'PcRPdsku': 31, 'NyPDKpZW': 57, 'raEsSsfI': 79, 'GHRtKwCq': 45, 'JApXpVmN': 27, 'HuVPVSNi': 53, 'HLUdfHgA': 58, 'apVYLvVs': 17, 'etsvDcAY': 50, 'BrNLfQGk': 30, 'vagZOBDr': 61, 'EmptHziW': 39, 'YoDyVGjG': 48, 'cfWBRNMO': 59, 'NSXRZsqG': 72, 'DnOcjrxB': 9, 'YgkiRlJk': 12, 'mFGHLgRV': 41, 'jUTQzrEE': 82, 'RzaZnyYc': 1, 'zKQbUatA': 98, 'iPfMrTIF': 97, 'JmrWHfoM': 59, 'TMHsmiKm': 50, 'eJEJGQWP': 60, 'vbcVzAYh': 55, 'LFBdCwPE': 66, 'ctjZJaan': 43, 'miNQMuUH': 33, 'xTzfppVO': 53, 'YnzkZPGH': 32, 'lHafErqM': 93, 'jmLTUkah': 5, 'KSDuhtOQ': 9, 'wmbwcLom': 46, 'CztccWcP': 21, 'duJxKXHO': 84, 'JpRPIbCV': 70, 'oQqSUiNj': 34, 'rxhabTjS': 81, 'AlwqnFZA': 99, 'GDeVCOAe': 73, 'fqbayTdQ': 49, 'cDpHSwfg': 95, 'kgmWFwHw': 55, 'EQipZnEE': 53}
# Relationship Costs: Transportation -
('OHMPdqhW', 35.92), ('fuHchKVj', 31.75), ('LqjTKKjM', 13.5), ('keRmzshc', 11.9), ('qQpWHRZc', 8.32)]
# Parts Nearing Expiry: ['ygsRsQcu', 'uDlTiStl', 'WjTrWyRX', 'RHkJiQUn', 'EmsXEQOs', 'GzocVWAA', 'ByVvXOym', 'qHDXoFLb', 'umxwvkyh', 'kMEKiNsb', 'wsbZORtO', 'pWlWfuAt']
# Average Demand for Product Offerings: 53.166666666666664
# Total Operating Cost of Facilities: 12594.01
# Safety Stock Levels in Warehouses: {'eWchZYRX': 65, 'nluhoZdu': 77, 'vWCkUCQm': 90, 'yTiAZsDi': 16, 'iNcMvIVA': 81, 'vJpOqyeC': 70, 'DVfHDlMR': 9, 'SWUFfMZs': 74, 'lsXnhHdH': 37, 'pnSNuMeB': 25, 'vgHNfewY': 36, 'JRZvwomO': 9, 'JigUivKh': 77, 'HDKTRhTB': 96, 'EKhUatdS': 40, 'mSojwEoo': 19, 'NeJPTjwN': 80, 'pliEyEhh': 72, 'CRWsHVzw': 15, 'hFHXNsCU': 46, 'PGfHaPZa': 71, 'LDXFmTRI': 96, 'YVgbJLSQ': 86, 'kgKtWSWC': 67, 'mHyyGadG': 16, 'uGQAiaBo': 92, 'DHyPKhMa': 27, 'VjjATpac': 73, 'QQoxDPdM': 84, 'iOnHNywh': 44, 'gBKpmXxD': 15, 'BPGIWpYC': 44, 'FojiaqBS': 56, 'UkchKLSz': 68, 'IxRTeKJB': 88, 'dCIkcCWQ': 99, 'YXarmeNj': 48, 'ARdZDKGE': 82, 'HngpzLVj': 69, 'AdvEmBnJ': 68, 'FcqRMWIn': 1, 'XBIlHvoW': 15, 'iVlGyuMr': 50, 'HshRmseY': 58, 'ptTncHvq': 50, 'ozTOGmgV': 31, 'kXiPYyAv': 55, 'qTMvFCXQ': 53, 'pBLEjLXO': 24, 'mYSfVLit': 100, 'qWpWSvGM': 86, 'HTyXEoAY': 53, 'tBkAvFoZ': 32, 'hrKwABOW': 41, 'XRCqzEjv': 31, 'NyPDKpZW': 57, 'raEsSsfI': 79, 'GHRtKwCq': 95, 'ECSxaxOI': 27, 'HuVPVSNi': 53, 'HLUdfHgA': 58, 'NZidaBka': 17, 'yVFqIkqS': 50, 'BrNLfQGk': 30, 'vagZOBDr': 61, 'EmptHziW': 39, 'YoDyVGjG': 48, 'cfWBRNMO': 59, 'NSXRZsqG': 72, 'DnOcjrxB': 9, 'eehHOsJT': 33, 'mFGHLgRV': 41, 'jUTQzrEE': 82, 'RzaZnyYc': 1, 'oWdonsOG': 32, 'riaSdsfk': 97, 'JmrWHfoM': 59, 'hVEFqOfw': 50, 'eJEJGQWP': 60, 'vbcVzAYh': 55, 'uJglPxYb': 56, 'sLzfEGib': 78, 'miNQMuUH': 33, 'YwPYkrXb': 53, 'qYJdVMus': 51, 'lHafErqM': 93, 'jmLTUkah': 5, 'KSDuhtOQ': 9, 'UZdKqPlG': 46, 'CztccWcP': 21, 'VOXhvrPr': 84, 'uOyiSmZa': 60, 'oQqSUiNj': 34, 'rxhabTjS': 81, 'AlwqnFZA': 99, 'KLrNwkkM': 55, 'CfaMuDqU': 29, 'WGSNNlnp': 95, 'kgmWFwHw': 55, 'EQipZnEE': 92}
# Relationship Costs: Transportation - 99604.40000000005, Storage - 104711.40999999993
# Nodes Created After Timestamp: []
# Results for 11.json:
# Revenue by Business Unit: {'YbdbTWFN': 468.51, 'gQxtAGMj': 186.06, 'uhTkgszG': 29.91}
# Total Cost of Product Offerings: 3773.5600000000004
# Facility Utilization: {'vdTkFiIn': 82, 'bBzjgTay': 9, 'egQMaRqe': 10, 'vVSuldYi': 26, 'zbYQkDOz': 29, 'gWdjApIt': 48, 'DUBEirbR': 42, 'gEVLdKwA': 33, 'kwBNCAUp': 62, 'cYxJYjPe': 25, 'tLgtoBiM': 14, 'aePRdVyh': 6, 'vNDDpWge': 29, 'oXzmjPSW': 20, 'XaBJDgIW': 98, 'kshZRZFD': 56, 'MlUbawCs': 43, 'QkguXeuz': 51, 'MIBkvcne': 89, 'xkRbHPVZ': 74, 'JvBOKLxk': 66, 'TloxfXMr': 80, 'KoUNFcHc': 47, 'CwWgxpoE': 3}
# Supplier Reliability: [('mBDYhRUe', 992.95), ('fueIsZkc', 990.85), ('HCXvstLl', 972.4), ('oLIAZrge', 968.13), ('kyavilmB', 959.21), ('SWHzXxPD', 955.29), ('MvtJOGdi', 954.44), ('xEjyDNqh', 951.68), ('GqKIGLAA', 950.49), ('oGoHWqPy', 917.6), ('OjSWxZkP', 907.93), ('EBcWZVEX', 905.0), ('uPBrfTGk', 891.52), ('ZXhHBKop', 869.36), ('oFxYzTQW', 868.18), ('ibBzRKvH', 864.46), ('qgIiTrDH', 850.06), ('uuoheTXr', 840.12), ('NGjDaYVZ', 831.62), ('oIxwOrMK', 807.21), ('FuPYBvTP', 801.13), ('xVBbpeqO', 781.76), ('msrZeITP', 772.96), ('UKRIJhuX', 751.1), ('hptsISDN', 750.6), ('fxyBdhfx', 749.1), ('BwpiFPRP', 737.83), ('rwIhCkHV', 733.24), ('KauYdcnH', 727.34), ('XgQVgVhM', 690.24), ('rccRPnLW', 686.26), ('xXsoTdar', 685.7), ('QJybIRve', 683.81), ('gWarQGpU', 677.39), ('EXSvCSjf', 656.21), ('lsqoJfaB', 645.52), ('VTbAhENr', 638.17), ('NUUIkHeO', 612.6), ('INphtuSR', 598.98), ('lbIyQHlG', 579.23), ('oRBjbfjs', 578.97), ('oNplGQJZ', 577.39), ('CqRIAGAX', 564.19), ('qKmlQjfl', 556.48), ('SuGKLEqb', 554.39), ('IWCMdagu', 553.25), ('YvuVjZTS', 505.8), ('PvrRmTNY', 492.84), ('AkeuISed', 485.37), ('WKhRGLBd', 481.76), ('mxIEYanm', 462.38), ('LJhuemeN', 461.41), ('tqbnlxRi', 448.46), ('JLTrRict', 429.94), ('oiTydaWU', 424.69), ('IlAfsaOw', 422.8), ('kbFJZptm', 412.04), ('IIpeZcvf', 401.17), ('gyyNoFOp', 379.32), ('WbwosCUk', 372.33), ('tGRHwQDg', 371.28), ('hmqBuMxt', 357.17), ('sgYRaUsd', 355.26), ('NEYJEXuO', 353.71), ('mVDuZyxx', 352.63), ('LXZnpOIZ', 351.04), ('ASxvNODQ', 346.32), ('LpeSpdCl', 330.43), ('SzUCaQjS', 330.41), ('CJshkOVJ', 317.43), ('oydwHkto', 315.35), ('QdeHzqWs', 310.23), ('OlzYWvzC', 303.94), ('ydMdYXlZ', 301.14), ('IxgvseUC', 271.78), ('WWfkiorT', 266.45), ('oYTHYjgI', 265.97), ('JDwrxaAD', 263.46), ('FkejbOtI', 257.86), ('fyCYjFNX', 255.88), ('nliFSzin', 239.15), ('pYUPDEOo', 219.99), ('KsTpCCCl', 216.86), ('jYArdIik', 204.44), ('xekDXkqP', 202.88), ('ByRaQhxV', 180.73), ('bwZZSEFG', 172.78), ('fJVRuMDh', 139.46), ('YInIpBcB', 129.31), ('sXRKXSNK', 89.34), ('VHkehmdq', 81.29), ('gofQqFCS', 79.86), ('wDsmrfEo', 71.99), ('rChEXGly', 70.37), ('fuHchKVj', 31.75), ('tuLJwjOU', 23.61), ('QNcmTOWr', 16.82), ('LqjTKKjM', 13.5), ('keRmzshc', 11.9), ('qQpWHRZc', 8.32)]
# Parts Nearing Expiry: ['ygsRsQcu', 'AfsvQsvS', 'uDlTiStl', 'WjTrWyRX', 'nsLgYdJU', 'GPvowryr', 'GzocVWAA', 'umxwvkyh', 'CzRuwvIU', 'FamzNWaJ', 'onLlVkVt', 'rbVlqUAA', 'oMgwwWuK', 'MMHCcxts']
# Average Demand for Product Offerings: 49.416666666666664
# Total Operating Cost of Facilities: 11739.380000000001
# Safety Stock Levels in Warehouses: {'eWchZYRX': 65, 'IiwAGNSn': 77, 'vWCkUCQm': 11, 'yTiAZsDi': 8, 'iNcMvIVA': 81, 'vJpOqyeC': 70, 'wxvqmwqT': 18, 'SWUFfMZs': 74, 'lsXnhHdH': 37, 'pSWYIzXa': 25, 'vgHNfewY': 36, 'JRZvwomO': 9, 'JigUivKh': 77, 'HDKTRhTB': 96, 'EKhUatdS': 40, 'mSojwEoo': 77, 'izkuayyI': 80, 'wwVFELoF': 72, 'CRWsHVzw': 15, 'hFHXNsCU': 46, 'PGfHaPZa': 71, 'LDXFmTRI': 96, 'YVgbJLSQ': 86, 'kgKtWSWC': 67, 'mHyyGadG': 16, 'uGQAiaBo': 92, 'DHyPKhMa': 5, 'VjjATpac': 73, 'QQoxDPdM': 59, 'iOnHNywh': 84, 'gBKpmXxD': 15, 'BPGIWpYC': 44, 'bifliefn': 93, 'aWHmDNrx': 68, 'IxRTeKJB': 88, 'dCIkcCWQ': 99, 'YXarmeNj': 48, 'WRGvDFLP': 82, 'cpyNAMuv': 69, 'GZshKMTK': 68, 'FcqRMWIn': 49, 'PtzHvAAQ': 15, 'eOSUmSxC': 50, 'HshRmseY': 58, 'ptTncHvq': 50, 'FEGGwrsi': 31, 'kXiPYyAv': 55, 'qTMvFCXQ': 53, 'pBLEjLXO': 24, 'mYSfVLit': 100, 'zxXYzuAt': 85, 'HTyXEoAY': 53, 'tBkAvFoZ': 32, 'hrKwABOW': 41, 'PcRPdsku': 31, 'NyPDKpZW': 57, 'raEsSsfI': 79, 'GHRtKwCq': 45, 'JApXpVmN': 27, 'HuVPVSNi': 53, 'HLUdfHgA': 58, 'apVYLvVs': 17, 'etsvDcAY': 50, 'BrNLfQGk': 30, 'vagZOBDr': 61, 'EmptHziW': 39, 'YoDyVGjG': 48, 'cfWBRNMO': 59, 'NSXRZsqG': 72, 'DnOcjrxB': 9, 'YgkiRlJk': 12, 'mFGHLgRV': 41, 'jUTQzrEE': 82, 'RzaZnyYc': 1, 'zKQbUatA': 98, 'iPfMrTIF': 97, 'JmrWHfoM': 59, 'TMHsmiKm': 50, 'eJEJGQWP': 60, 'vbcVzAYh': 55, 'LFBdCwPE': 66, 'ctjZJaan': 43, 'miNQMuUH': 33, 'xTzfppVO': 53, 'YnzkZPGH': 32, 'lHafErqM': 93, 'jmLTUkah': 5, 'KSDuhtOQ': 9, 'wmbwcLom': 46, 'CztccWcP': 21, 'duJxKXHO': 84, 'JpRPIbCV': 70, 'oQqSUiNj': 34, 'rxhabTjS': 81, 'AlwqnFZA': 99, 'GDeVCOAe': 73, 'fqbayTdQ': 49, 'cDpHSwfg': 95, 'kgmWFwHw': 55, 'EQipZnEE': 53}
# Relationship Costs: Transportation - 98886.25000000009, Storage - 100915.54999999994
# Nodes Created After Timestamp: []
# Results for 12.json:
# Revenue by Business Unit: {'YbdbTWFN': 468.51, 'gQxtAGMj': 186.06, 'uhTkgszG': 29.91}
# Total Cost of Product Offerings: 3773.5600000000004
# Facility Utilization: {'vdTkFiIn': 82, 'bBzjgTay': 9, 'egQMaRqe': 10, 'vVSuldYi': 26, 'zbYQkDOz': 29, 'gWdjApIt': 48, 'DUBEirbR': 42, 'gEVLdKwA': 33, 'kwBNCAUp': 62, 'cYxJYjPe': 25, 'tLgtoBiM': 14, 'aePRdVyh': 6, 'vNDDpWge': 29, 'oXzmjPSW': 20, 'XaBJDgIW': 98, 'kshZRZFD': 56, 'MlUbawCs': 43, 'QkguXeuz': 51, 'MIBkvcne': 89, 'xkRbHPVZ': 74, 'JvBOKLxk': 66, 'TloxfXMr': 80, 'KoUNFcHc': 47, 'CwWgxpoE': 3}
# Supplier Reliability: [('mBDYhRUe', 992.95), ('fueIsZkc', 990.85), ('HCXvstLl', 972.4), ('oLIAZrge', 968.13), ('kyavilmB', 959.21), ('SWHzXxPD', 955.29), ('MvtJOGdi', 954.44), ('xEjyDNqh', 951.68), ('GqKIGLAA', 950.49), ('oGoHWqPy', 917.6), ('OjSWxZkP', 907.93), ('EBcWZVEX', 905.0), ('uPBrfTGk', 891.52), ('ZXhHBKop', 869.36), ('oFxYzTQW', 868.18), ('qgIiTrDH', 850.06), ('uuoheTXr', 840.12), ('NGjDaYVZ', 831.62), ('oIxwOrMK', 807.21), ('FuPYBvTP', 801.13), ('xVBbpeqO', 781.76), ('msrZeITP', 772.96), ('UKRIJhuX', 751.1), ('hptsISDN', 750.6), ('fxyBdhfx', 749.1), ('BwpiFPRP', 737.83), ('rwIhCkHV', 733.24), ('KauYdcnH', 727.34), ('XgQVgVhM', 690.24), ('rccRPnLW', 686.26), ('xXsoTdar', 685.7), ('QJybIRve', 683.81), ('gWarQGpU', 677.39), ('EXSvCSjf', 656.21), ('lsqoJfaB', 645.52), ('VTbAhENr', 638.17), ('NUUIkHeO', 612.6), ('BpSUjpVX', 609.09), ('INphtuSR', 598.98), ('lbIyQHlG', 579.23), ('oRBjbfjs', 578.97), ('oNplGQJZ', 577.39), ('CqRIAGAX', 564.19), ('qKmlQjfl', 556.48), ('SuGKLEqb', 554.39), ('IWCMdagu', 553.25), ('YvuVjZTS', 505.8), ('AkeuISed', 485.37), ('WKhRGLBd', 481.76), ('mxIEYanm', 462.38), ('LJhuemeN', 461.41), ('tqbnlxRi', 448.46), ('JLTrRict', 429.94), ('oiTydaWU', 424.69), ('IlAfsaOw', 422.8), ('kbFJZptm', 412.04), ('IIpeZcvf', 401.17), ('gyyNoFOp', 379.32), ('ibBzRKvH', 376.19), ('WbwosCUk', 372.33), ('tGRHwQDg', 371.28), ('hmqBuMxt', 357.17), ('sgYRaUsd', 355.26), ('NEYJEXuO', 353.71), ('mVDuZyxx', 352.63), ('LXZnpOIZ', 351.04), ('ASxvNODQ', 346.32), ('LpeSpdCl', 330.43), ('SzUCaQjS', 330.41), ('CJshkOVJ', 317.43), ('oydwHkto', 315.35), ('QdeHzqWs', 310.23), ('OlzYWvzC', 303.94), ('ydMdYXlZ', 301.14), ('IxgvseUC', 271.78), ('WWfkiorT', 266.45), ('oYTHYjgI', 265.97), ('JDwrxaAD', 263.46), ('FkejbOtI', 257.86), ('fyCYjFNX', 255.88), ('nliFSzin', 239.15), ('pYUPDEOo', 219.99), ('KsTpCCCl', 216.86), ('jYArdIik', 204.44), ('xekDXkqP', 202.88), ('ByRaQhxV', 180.73), ('bwZZSEFG', 172.78), ('fJVRuMDh', 139.46), ('YInIpBcB', 129.31), ('sXRKXSNK', 89.34), ('VHkehmdq', 81.29), ('gofQqFCS', 79.86), ('wDsmrfEo', 71.99), ('rChEXGly', 70.37), ('OHMPdqhW', 35.92), ('fuHchKVj', 31.75), ('QNcmTOWr', 16.82), ('LqjTKKjM', 13.5), ('keRmzshc', 11.9), ('qQpWHRZc', 8.32)]
# Parts Nearing Expiry: ['ygsRsQcu', 'AfsvQsvS', 'uDlTiStl', 'WjTrWyRX', 'nsLgYdJU', 'GPvowryr', 'GzocVWAA', 'umxwvkyh', 'CzRuwvIU', 'FamzNWaJ', 'onLlVkVt', 'rbVlqUAA', 'oMgwwWuK', 'MMHCcxts']
# Average Demand for Product Offerings: 51.166666666666664
# Total Operating Cost of Facilities: 11591.04
# Safety Stock Levels in Warehouses: {'eWchZYRX': 65, 'IiwAGNSn': 77, 'vWCkUCQm': 11, 'yTiAZsDi': 8, 'iNcMvIVA': 81, 'vJpOqyeC': 70, 'wxvqmwqT': 18, 'SWUFfMZs': 74, 'lsXnhHdH': 37, 'pSWYIzXa': 25, 'vgHNfewY': 36, 'JRZvwomO': 9, 'JigUivKh': 77, 'HDKTRhTB': 96, 'EKhUatdS': 40, 'mSojwEoo': 77, 'izkuayyI': 80, 'wwVFELoF': 72, 'CRWsHVzw': 15, 'hFHXNsCU': 46, 'PGfHaPZa': 71, 'LDXFmTRI': 96, 'YVgbJLSQ': 86, 'kgKtWSWC': 67, 'mHyyGadG': 16, 'uGQAiaBo': 92, 'DHyPKhMa': 5, 'VjjATpac': 73, 'QQoxDPdM': 59, 'iOnHNywh': 84, 'gBKpmXxD': 15, 'BPGIWpYC': 44, 'bifliefn': 93, 'aWHmDNrx': 68, 'IxRTeKJB': 88, 'dCIkcCWQ': 99, 'YXarmeNj': 48, 'WRGvDFLP': 82, 'cpyNAMuv': 69, 'GZshKMTK': 68, 'FcqRMWIn': 49, 'PtzHvAAQ': 15, 'eOSUmSxC': 50, 'HshRmseY': 58, 'ptTncHvq': 50, 'FEGGwrsi': 31, 'kXiPYyAv': 55, 'qTMvFCXQ': 53, 'pBLEjLXO': 24, 'mYSfVLit': 100, 'zxXYzuAt': 85, 'HTyXEoAY': 53, 'tBkAvFoZ': 32, 'hrKwABOW': 41, 'PcRPdsku': 31, 'NyPDKpZW': 57, 'raEsSsfI': 79, 'GHRtKwCq': 45, 'JApXpVmN': 27, 'HuVPVSNi': 53, 'HLUdfHgA': 58, 'apVYLvVs': 17, 'etsvDcAY': 50, 'BrNLfQGk': 30, 'vagZOBDr': 61, 'EmptHziW': 39, 'YoDyVGjG': 48, 'cfWBRNMO': 59, 'NSXRZsqG': 72, 'DnOcjrxB': 9, 'YgkiRlJk': 12, 'mFGHLgRV': 41, 'jUTQzrEE': 82, 'RzaZnyYc': 1, 'zKQbUatA': 98, 'iPfMrTIF': 97, 'JmrWHfoM': 59, 'TMHsmiKm': 50, 'eJEJGQWP': 60, 'vbcVzAYh': 55, 'LFBdCwPE': 66, 'ctjZJaan': 43, 'miNQMuUH': 33, 'xTzfppVO': 53, 'YnzkZPGH': 32, 'lHafErqM': 93, 'jmLTUkah': 5, 'KSDuhtOQ': 9, 'wmbwcLom': 46, 'CztccWcP': 21, 'duJxKXHO': 84, 'JpRPIbCV': 70, 'oQqSUiNj': 34, 'rxhabTjS': 81, 'AlwqnFZA': 99, 'GDeVCOAe': 73, 'fqbayTdQ': 49, 'cDpHSwfg': 95, 'kgmWFwHw': 55, 'EQipZnEE': 53}
# Relationship Costs: Transportation - 99362.71000000008, Storage - 100915.54999999994
# Nodes Created After Timestamp: []
# Results for 13.json:
# Revenue by Business Unit: {'YbdbTWFN': 468.51, 'gQxtAGMj': 186.06, 'uhTkgszG': 20.1}
# Total Cost of Product Offerings: 3773.5600000000004
# Facility Utilization: {'vdTkFiIn': 82, 'bBzjgTay': 9, 'egQMaRqe': 10, 'vVSuldYi': 26, 'zbYQkDOz': 29, 'gWdjApIt': 48, 'DUBEirbR': 42, 'gEVLdKwA': 33, 'kwBNCAUp': 62, 'cYxJYjPe': 25, 'tLgtoBiM': 14, 'aePRdVyh': 6, 'vNDDpWge': 29, 'oXzmjPSW': 20, 'XaBJDgIW': 98, 'kshZRZFD': 56, 'MlUbawCs': 43, 'QkguXeuz': 51, 'MIBkvcne': 89, 'xkRbHPVZ': 74, 'JvBOKLxk': 66, 'TloxfXMr': 80, 'KoUNFcHc': 47, 'CwWgxpoE': 3}
# Supplier Reliability: [('mBDYhRUe', 992.95), ('fueIsZkc', 990.85), ('HCXvstLl', 972.4), ('oLIAZrge', 968.13), ('kyavilmB', 959.21), ('SWHzXxPD', 955.29), ('MvtJOGdi', 954.44), ('xEjyDNqh', 951.68), ('GqKIGLAA', 950.49), ('oGoHWqPy', 917.6), ('OjSWxZkP', 907.93), ('EBcWZVEX', 905.0), ('uPBrfTGk', 891.52), ('ZXhHBKop', 869.36), ('oFxYzTQW', 868.18), ('qgIiTrDH', 850.06), ('uuoheTXr', 840.12), ('NGjDaYVZ', 831.62), ('oIxwOrMK', 807.21), ('FuPYBvTP', 801.13), ('xVBbpeqO', 781.76), ('msrZeITP', 772.96), ('UKRIJhuX', 751.1), ('hptsISDN', 750.6), ('fxyBdhfx', 749.1), ('BwpiFPRP', 737.83), ('rwIhCkHV', 733.24), ('KauYdcnH', 727.34), ('XgQVgVhM', 690.24), ('rccRPnLW', 686.26), ('xXsoTdar', 685.7), ('QJybIRve', 683.81), ('gWarQGpU', 677.39), ('EXSvCSjf', 656.21), ('lsqoJfaB', 645.52), ('VTbAhENr', 638.17), ('NUUIkHeO', 612.6), ('BpSUjpVX', 609.09), ('INphtuSR', 598.98), ('lbIyQHlG', 579.23), ('oRBjbfjs', 578.97), ('oNplGQJZ', 577.39), ('CqRIAGAX', 564.19), ('qKmlQjfl', 556.48), ('SuGKLEqb', 554.39), ('IWCMdagu', 553.25), ('YvuVjZTS', 505.8), ('AkeuISed', 485.37), ('WKhRGLBd', 481.76), ('mxIEYanm', 462.38), ('LJhuemeN', 461.41), ('tqbnlxRi', 448.46), ('JLTrRict', 429.94), ('oiTydaWU', 424.69), ('IlAfsaOw', 422.8), ('kbFJZptm', 412.04), ('IIpeZcvf', 401.17), ('gyyNoFOp', 379.32), ('ibBzRKvH', 376.19), ('WbwosCUk', 372.33), ('tGRHwQDg', 371.28), ('hmqBuMxt', 357.17), ('sgYRaUsd', 355.26), ('NEYJEXuO', 353.71), ('mVDuZyxx', 352.63), ('LXZnpOIZ', 351.04), ('ASxvNODQ', 346.32), ('LpeSpdCl', 330.43), ('SzUCaQjS', 330.41), ('CJshkOVJ', 317.43), ('oydwHkto', 315.35), ('QdeHzqWs', 310.23), ('OlzYWvzC', 303.94), ('ydMdYXlZ', 301.14), ('IxgvseUC', 271.78), ('WWfkiorT', 266.45), ('oYTHYjgI', 265.97), ('JDwrxaAD', 263.46), ('FkejbOtI', 257.86), ('fyCYjFNX', 255.88), ('nliFSzin', 239.15), ('pYUPDEOo', 219.99), ('KsTpCCCl', 216.86), ('jYArdIik', 204.44), ('xekDXkqP', 202.88), ('ByRaQhxV', 180.73), ('bwZZSEFG', 172.78), ('fJVRuMDh', 139.46), ('YInIpBcB', 129.31), ('sXRKXSNK', 89.34), ('VHkehmdq', 81.29), ('gofQqFCS', 79.86), ('wDsmrfEo', 71.99), ('rChEXGly', 70.37), ('OHMPdqhW', 35.92), ('fuHchKVj', 31.75), ('QNcmTOWr', 16.82), ('LqjTKKjM', 13.5), ('keRmzshc', 11.9), ('qQpWHRZc', 8.32)]
# Parts Nearing Expiry: ['ygsRsQcu', 'AfsvQsvS', 'uDlTiStl', 'WjTrWyRX', 'nsLgYdJU', 'GPvowryr', 'GzocVWAA', 'umxwvkyh', 'CzRuwvIU', 'FamzNWaJ', 'onLlVkVt', 'rbVlqUAA', 'oMgwwWuK', 'MMHCcxts']
# Average Demand for Product Offerings: 51.166666666666664
# Total Operating Cost of Facilities: 11608.7
# Safety Stock Levels in Warehouses: {'eWchZYRX': 65, 'IiwAGNSn': 77, 'vWCkUCQm': 11, 'yTiAZsDi': 8, 'iNcMvIVA': 81, 'vJpOqyeC': 70, 'wxvqmwqT': 18, 'SWUFfMZs': 74, 'lsXnhHdH': 37, 'pSWYIzXa': 25, 'vgHNfewY': 36, 'JRZvwomO': 9, 'JigUivKh': 77, 'HDKTRhTB': 96, 'EKhUatdS': 40, 'mSojwEoo': 77, 'izkuayyI': 80, 'wwVFELoF': 72, 'CRWsHVzw': 15, 'hFHXNsCU': 46, 'PGfHaPZa': 71, 'LDXFmTRI': 96, 'YVgbJLSQ': 86, 'kgKtWSWC': 67, 'mHyyGadG': 16, 'uGQAiaBo': 92, 'DHyPKhMa': 5, 'VjjATpac': 73, 'QQoxDPdM': 59, 'iOnHNywh': 84, 'gBKpmXxD': 15, 'BPGIWpYC': 44, 'bifliefn': 93, 'aWHmDNrx': 68, 'IxRTeKJB': 88, 'dCIkcCWQ': 99, 'YXarmeNj': 48, 'WRGvDFLP': 82, 'cpyNAMuv': 69, 'GZshKMTK': 68, 'FcqRMWIn': 1, 'PtzHvAAQ': 15, 'eOSUmSxC': 50, 'HshRmseY': 58, 'ptTncHvq': 50, 'FEGGwrsi': 31, 'kXiPYyAv': 55, 'qTMvFCXQ': 53, 'pBLEjLXO': 24, 'mYSfVLit': 100, 'zxXYzuAt': 85, 'HTyXEoAY': 53, 'tBkAvFoZ': 32, 'hrKwABOW': 41, 'PcRPdsku': 31, 'NyPDKpZW': 57, 'raEsSsfI': 79, 'GHRtKwCq': 45, 'JApXpVmN': 27, 'HuVPVSNi': 53, 'HLUdfHgA': 58, 'apVYLvVs': 17, 'etsvDcAY': 50, 'BrNLfQGk': 30, 'vagZOBDr': 61, 'EmptHziW': 39, 'YoDyVGjG': 48, 'cfWBRNMO': 59, 'NSXRZsqG': 72, 'DnOcjrxB': 9, 'YgkiRlJk': 12, 'mFGHLgRV': 41, 'jUTQzrEE': 82, 'RzaZnyYc': 1, 'zKQbUatA': 98, 'iPfMrTIF': 97, 'JmrWHfoM': 59, 'TMHsmiKm': 50, 'eJEJGQWP': 60, 'vbcVzAYh': 55, 'LFBdCwPE': 66, 'ctjZJaan': 43, 'miNQMuUH': 33, 'xTzfppVO': 53, 'YnzkZPGH': 32, 'lHafErqM': 93, 'jmLTUkah': 5, 'KSDuhtOQ': 9, 'wmbwcLom': 46, 'CztccWcP': 21, 'duJxKXHO': 84, 'JpRPIbCV': 70, 'oQqSUiNj': 34, 'rxhabTjS': 81, 'AlwqnFZA': 99, 'GDeVCOAe': 73, 'fqbayTdQ': 49, 'cDpHSwfg': 95, 'kgmWFwHw': 55, 'EQipZnEE': 53}
# Relationship Costs: Transportation - 99362.71000000008, Storage - 100915.54999999994
# Nodes Created After Timestamp: []
# Results for 14.json:
# Revenue by Business Unit: {'YbdbTWFN': 468.51, 'gQxtAGMj': 186.06, 'uhTkgszG': 20.1}
# Total Cost of Product Offerings: 3809.1900000000005
# Facility Utilization: {'vdTkFiIn': 82, 'bBzjgTay': 9, 'egQMaRqe': 10, 'vVSuldYi': 26, 'zbYQkDOz': 29, 'gWdjApIt': 48, 'DUBEirbR': 42, 'gEVLdKwA': 33, 'kwBNCAUp': 62, 'cYxJYjPe': 25, 'tLgtoBiM': 14, 'aePRdVyh': 6, 'vNDDpWge': 29, 'oXzmjPSW': 20, 'XaBJDgIW': 98, 'kshZRZFD': 56, 'MlUbawCs': 43, 'QkguXeuz': 51, 'MIBkvcne': 89, 'xkRbHPVZ': 74, 'JvBOKLxk': 66, 'TloxfXMr': 80, 'KoUNFcHc': 47, 'CwWgxpoE': 3}
# Supplier Reliability: [('mBDYhRUe', 992.95), ('fueIsZkc', 990.85), ('HCXvstLl', 972.4), ('oLIAZrge', 968.13), ('kyavilmB', 959.21), ('SWHzXxPD', 955.29), ('MvtJOGdi', 954.44), ('xEjyDNqh', 951.68), ('GqKIGLAA', 950.49), ('oGoHWqPy', 917.6), ('OjSWxZkP', 907.93), ('EBcWZVEX', 905.0), ('uPBrfTGk', 891.52), ('ZXhHBKop', 869.36), ('oFxYzTQW', 868.18), ('qgIiTrDH', 850.06), ('uuoheTXr', 840.12), ('NGjDaYVZ', 831.62), ('oIxwOrMK', 807.21), ('FuPYBvTP', 801.13), ('xVBbpeqO', 781.76), ('msrZeITP', 772.96), ('UKRIJhuX', 751.1), ('hptsISDN', 750.6), ('fxyBdhfx', 749.1), ('BwpiFPRP', 737.83), ('rwIhCkHV', 733.24), ('KauYdcnH', 727.34), ('XgQVgVhM', 690.24), ('rccRPnLW', 686.26), ('xXsoTdar', 685.7), ('QJybIRve', 683.81), ('gWarQGpU', 677.39), ('EXSvCSjf', 656.21), ('lsqoJfaB', 645.52), ('VTbAhENr', 638.17), ('NUUIkHeO', 612.6), ('BpSUjpVX', 609.09), ('INphtuSR', 598.98), ('lbIyQHlG', 579.23), ('oRBjbfjs', 578.97), ('oNplGQJZ', 577.39), ('CqRIAGAX', 564.19), ('qKmlQjfl', 556.48), ('SuGKLEqb', 554.39), ('IWCMdagu', 553.25), ('YvuVjZTS', 505.8), ('AkeuISed', 485.37), ('WKhRGLBd', 481.76), ('mxIEYanm', 462.38), ('LJhuemeN', 461.41), ('tqbnlxRi', 448.46), ('JLTrRict', 429.94), ('oiTydaWU', 424.69), ('IlAfsaOw', 422.8), ('kbFJZptm', 412.04), ('IIpeZcvf', 401.17), ('gyyNoFOp', 379.32), ('ibBzRKvH', 376.19), ('WbwosCUk', 372.33), ('tGRHwQDg', 371.28), ('hmqBuMxt', 357.17), ('sgYRaUsd', 355.26), ('NEYJEXuO', 353.71), ('mVDuZyxx', 352.63), ('LXZnpOIZ', 351.04), ('ASxvNODQ', 346.32), ('LpeSpdCl', 330.43), ('SzUCaQjS', 330.41), ('CJshkOVJ', 317.43), ('oydwHkto', 315.35), ('QdeHzqWs', 310.23), ('OlzYWvzC', 303.94), ('ydMdYXlZ', 301.14), ('IxgvseUC', 271.78), ('WWfkiorT', 266.45), ('oYTHYjgI', 265.97), ('JDwrxaAD', 263.46), ('FkejbOtI', 257.86), ('fyCYjFNX', 255.88), ('nliFSzin', 239.15), ('pYUPDEOo', 219.99), ('KsTpCCCl', 216.86), ('jYArdIik', 204.44), ('xekDXkqP', 202.88), ('ByRaQhxV', 180.73), ('bwZZSEFG', 172.78), ('fJVRuMDh', 139.46), ('YInIpBcB', 129.31), ('sXRKXSNK', 89.34), ('VHkehmdq', 81.29), ('gofQqFCS', 79.86), ('wDsmrfEo', 71.99), ('rChEXGly', 70.37), ('OHMPdqhW', 35.92), ('fuHchKVj', 31.75), ('QNcmTOWr', 16.82), ('LqjTKKjM', 13.5), ('keRmzshc', 11.9), ('qQpWHRZc', 8.32)]
# Parts Nearing Expiry: ['ygsRsQcu', 'AfsvQsvS', 'uDlTiStl', 'WjTrWyRX', 'nsLgYdJU', 'GPvowryr', 'GzocVWAA', 'umxwvkyh', 'CzRuwvIU', 'FamzNWaJ', 'onLlVkVt', 'rbVlqUAA', 'oMgwwWuK', 'MMHCcxts']
# Average Demand for Product Offerings: 49.666666666666664
# Total Operating Cost of Facilities: 11608.7
# Safety Stock Levels in Warehouses: {'eWchZYRX': 65, 'IiwAGNSn': 77, 'vWCkUCQm': 11, 'yTiAZsDi': 8, 'iNcMvIVA': 81, 'vJpOqyeC': 70, 'wxvqmwqT': 18, 'SWUFfMZs': 74, 'lsXnhHdH': 37, 'pSWYIzXa': 25, 'vgHNfewY': 36, 'JRZvwomO': 9, 'JigUivKh': 77, 'HDKTRhTB': 96, 'EKhUatdS': 40, 'mSojwEoo': 77, 'izkuayyI': 80, 'wwVFELoF': 72, 'CRWsHVzw': 15, 'hFHXNsCU': 46, 'PGfHaPZa': 71, 'LDXFmTRI': 96, 'YVgbJLSQ': 86, 'kgKtWSWC': 67, 'mHyyGadG': 16, 'uGQAiaBo': 92, 'DHyPKhMa': 5, 'VjjATpac': 73, 'QQoxDPdM': 59, 'iOnHNywh': 84, 'gBKpmXxD': 15, 'BPGIWpYC': 44, 'bifliefn': 93, 'aWHmDNrx': 68, 'IxRTeKJB': 88, 'dCIkcCWQ': 99, 'YXarmeNj': 48, 'WRGvDFLP': 82, 'cpyNAMuv': 69, 'GZshKMTK': 68, 'FcqRMWIn': 1, 'PtzHvAAQ': 15, 'eOSUmSxC': 50, 'HshRmseY': 58, 'ptTncHvq': 50, 'FEGGwrsi': 31, 'kXiPYyAv': 55, 'qTMvFCXQ': 53, 'pBLEjLXO': 24, 'mYSfVLit': 100, 'zxXYzuAt': 85, 'HTyXEoAY': 53, 'tBkAvFoZ': 32, 'hrKwABOW': 41, 'PcRPdsku': 31, 'NyPDKpZW': 57, 'raEsSsfI': 79, 'GHRtKwCq': 45, 'JApXpVmN': 27, 'HuVPVSNi': 53, 'HLUdfHgA': 58, 'apVYLvVs': 17, 'etsvDcAY': 50, 'BrNLfQGk': 30, 'vagZOBDr': 61, 'EmptHziW': 39, 'YoDyVGjG': 48, 'cfWBRNMO': 59, 'NSXRZsqG': 72, 'DnOcjrxB': 9, 'YgkiRlJk': 12, 'mFGHLgRV': 41, 'jUTQzrEE': 82, 'RzaZnyYc': 1, 'zKQbUatA': 98, 'iPfMrTIF': 97, 'JmrWHfoM': 59, 'TMHsmiKm': 50, 'eJEJGQWP': 60, 'vbcVzAYh': 55, 'LFBdCwPE': 66, 'ctjZJaan': 43, 'miNQMuUH': 33, 'xTzfppVO': 53, 'YnzkZPGH': 32, 'lHafErqM': 93, 'jmLTUkah': 5, 'KSDuhtOQ': 9, 'wmbwcLom': 46, 'CztccWcP': 21, 'duJxKXHO': 84, 'JpRPIbCV': 70, 'oQqSUiNj': 34, 'rxhabTjS': 81, 'AlwqnFZA': 99, 'GDeVCOAe': 73, 'fqbayTdQ': 49, 'cDpHSwfg': 95, 'kgmWFwHw': 55, 'EQipZnEE': 53}
# Relationship Costs: Transportation - 99362.71000000008, Storage - 100915.54999999994
# Nodes Created After Timestamp: []
# Results for 15.json:
# Revenue by Business Unit: {'YbdbTWFN': 468.51, 'gQxtAGMj': 186.06, 'uhTkgszG': 20.1}
# Total Cost of Product Offerings: 4136.22
# Facility Utilization: {'vdTkFiIn': 82, 'bBzjgTay': 9, 'egQMaRqe': 10, 'vVSuldYi': 26, 'zbYQkDOz': 29, 'gWdjApIt': 48, 'DUBEirbR': 42, 'gEVLdKwA': 33, 'kwBNCAUp': 62, 'cYxJYjPe': 25, 'tLgtoBiM': 14, 'aePRdVyh': 6, 'vNDDpWge': 29, 'oXzmjPSW': 20, 'XaBJDgIW': 98, 'kshZRZFD': 56, 'MlUbawCs': 43, 'QkguXeuz': 51, 'MIBkvcne': 89, 'xkRbHPVZ': 74, 'JvBOKLxk': 66, 'TloxfXMr': 80, 'KoUNFcHc': 47, 'CwWgxpoE': 3}
# Supplier Reliability: [('mBDYhRUe', 992.95), ('fueIsZkc', 990.85), ('HCXvstLl', 972.4), ('oLIAZrge', 968.13), ('kyavilmB', 959.21), ('SWHzXxPD', 955.29), ('MvtJOGdi', 954.44), ('xEjyDNqh', 951.68), ('GqKIGLAA', 950.49), ('oGoHWqPy', 917.6), ('OjSWxZkP', 907.93), ('EBcWZVEX', 905.0), ('uPBrfTGk', 891.52), ('ZXhHBKop', 869.36), ('oFxYzTQW', 868.18), ('qgIiTrDH', 850.06), ('uuoheTXr', 840.12), ('NGjDaYVZ', 831.62), ('oIxwOrMK', 807.21), ('FuPYBvTP', 801.13), ('xVBbpeqO', 781.76), ('msrZeITP', 772.96), ('UKRIJhuX', 751.1), ('hptsISDN', 750.6), ('fxyBdhfx', 749.1), ('BwpiFPRP', 737.83), ('rwIhCkHV', 733.24), ('KauYdcnH', 727.34), ('XgQVgVhM', 690.24), ('rccRPnLW', 686.26), ('xXsoTdar', 685.7), ('QJybIRve', 683.81), ('gWarQGpU', 677.39), ('EXSvCSjf', 656.21), ('lsqoJfaB', 645.52), ('VTbAhENr', 638.17), ('NUUIkHeO', 612.6), ('BpSUjpVX', 609.09), ('INphtuSR', 598.98), ('lbIyQHlG', 579.23), ('oRBjbfjs', 578.97), ('oNplGQJZ', 577.39), ('CqRIAGAX', 564.19), ('qKmlQjfl', 556.48), ('SuGKLEqb', 554.39), ('IWCMdagu', 553.25), ('YvuVjZTS', 505.8), ('AkeuISed', 485.37), ('WKhRGLBd', 481.76), ('mxIEYanm', 462.38), ('LJhuemeN', 461.41), ('tqbnlxRi', 448.46), ('JLTrRict', 429.94), ('oiTydaWU', 424.69), ('IlAfsaOw', 422.8), ('kbFJZptm', 412.04), ('IIpeZcvf', 401.17), ('gyyNoFOp', 379.32), ('ibBzRKvH', 376.19), ('WbwosCUk', 372.33), ('tGRHwQDg', 371.28), ('hmqBuMxt', 357.17), ('sgYRaUsd', 355.26), ('NEYJEXuO', 353.71), ('mVDuZyxx', 352.63), ('LXZnpOIZ', 351.04), ('ASxvNODQ', 346.32), ('LpeSpdCl', 330.43), ('SzUCaQjS', 330.41), ('CJshkOVJ', 317.43), ('oydwHkto', 315.35), ('QdeHzqWs', 310.23), ('OlzYWvzC', 303.94), ('ydMdYXlZ', 301.14), ('IxgvseUC', 271.78), ('WWfkiorT', 266.45), ('oYTHYjgI', 265.97), ('JDwrxaAD', 263.46), ('FkejbOtI', 257.86), ('fyCYjFNX', 255.88), ('nliFSzin', 239.15), ('pYUPDEOo', 219.99), ('KsTpCCCl', 216.86), ('jYArdIik', 204.44), ('xekDXkqP', 202.88), ('ByRaQhxV', 180.73), ('bwZZSEFG', 172.78), ('fJVRuMDh', 139.46), ('YInIpBcB', 129.31), ('sXRKXSNK', 89.34), ('VHkehmdq', 81.29), ('gofQqFCS', 79.86), ('wDsmrfEo', 71.99), ('rChEXGly', 70.37), ('OHMPdqhW', 35.92), ('fuHchKVj', 31.75), ('QNcmTOWr', 16.82), ('LqjTKKjM', 13.5), ('keRmzshc', 11.9), ('qQpWHRZc', 8.32)]
# Parts Nearing Expiry: ['ygsRsQcu', 'AfsvQsvS', 'uDlTiStl', 'WjTrWyRX', 'nsLgYdJU', 'GPvowryr', 'GzocVWAA', 'umxwvkyh', 'CzRuwvIU', 'FamzNWaJ', 'onLlVkVt', 'rbVlqUAA', 'oMgwwWuK', 'MMHCcxts']
# Average Demand for Product Offerings: 49.666666666666664
# Total Operating Cost of Facilities: 11608.7
# Safety Stock Levels in Warehouses: {'eWchZYRX': 65, 'IiwAGNSn': 77, 'vWCkUCQm': 11, 'yTiAZsDi': 8, 'iNcMvIVA': 81, 'vJpOqyeC': 70, 'wxvqmwqT': 18, 'SWUFfMZs': 74, 'lsXnhHdH': 37, 'pSWYIzXa': 25, 'vgHNfewY': 36, 'JRZvwomO': 9, 'JigUivKh': 77, 'HDKTRhTB': 96, 'EKhUatdS': 40, 'mSojwEoo': 77, 'izkuayyI': 80, 'wwVFELoF': 72, 'CRWsHVzw': 15, 'hFHXNsCU': 46, 'PGfHaPZa': 71, 'LDXFmTRI': 96, 'YVgbJLSQ': 86, 'kgKtWSWC': 67, 'mHyyGadG': 16, 'uGQAiaBo': 92, 'DHyPKhMa': 27, 'VjjATpac': 73, 'QQoxDPdM': 59, 'iOnHNywh': 84, 'gBKpmXxD': 15, 'BPGIWpYC': 44, 'bifliefn': 93, 'aWHmDNrx': 68, 'IxRTeKJB': 88, 'dCIkcCWQ': 99, 'YXarmeNj': 48, 'WRGvDFLP': 82, 'cpyNAMuv': 69, 'GZshKMTK': 68, 'FcqRMWIn': 1, 'PtzHvAAQ': 15, 'eOSUmSxC': 50, 'HshRmseY': 58, 'ptTncHvq': 50, 'FEGGwrsi': 31, 'kXiPYyAv': 55, 'qTMvFCXQ': 53, 'pBLEjLXO': 24, 'mYSfVLit': 100, 'zxXYzuAt': 85, 'HTyXEoAY': 53, 'tBkAvFoZ': 32, 'hrKwABOW': 41, 'PcRPdsku': 31, 'NyPDKpZW': 57, 'raEsSsfI': 79, 'GHRtKwCq': 45, 'JApXpVmN': 27, 'HuVPVSNi': 53, 'HLUdfHgA': 58, 'apVYLvVs': 17, 'etsvDcAY': 50, 'BrNLfQGk': 30, 'vagZOBDr': 61, 'EmptHziW': 39, 'YoDyVGjG': 48, 'cfWBRNMO': 59, 'NSXRZsqG': 72, 'DnOcjrxB': 9, 'YgkiRlJk': 12, 'mFGHLgRV': 41, 'jUTQzrEE': 82, 'RzaZnyYc': 1, 'zKQbUatA': 32, 'iPfMrTIF': 97, 'JmrWHfoM': 59, 'TMHsmiKm': 50, 'eJEJGQWP': 60, 'vbcVzAYh': 55, 'LFBdCwPE': 66, 'ctjZJaan': 43, 'miNQMuUH': 33, 'xTzfppVO': 53, 'YnzkZPGH': 32, 'lHafErqM': 93, 'jmLTUkah': 5, 'KSDuhtOQ': 9, 'wmbwcLom': 46, 'CztccWcP': 21, 'duJxKXHO': 84, 'JpRPIbCV': 70, 'oQqSUiNj': 34, 'rxhabTjS': 81, 'AlwqnFZA': 99, 'GDeVCOAe': 73, 'fqbayTdQ': 49, 'cDpHSwfg': 95, 'kgmWFwHw': 55, 'EQipZnEE': 53}
# Relationship Costs: Transportation - 99362.71000000008, Storage - 100915.54999999994
# Nodes Created After Timestamp: []
# Results for 16.json:
# Revenue by Business Unit: {'YbdbTWFN': 468.51, 'gQxtAGMj': 186.06, 'uhTkgszG': 20.1}
# Total Cost of Product Offerings: 4136.22
# Facility Utilization: {'vdTkFiIn': 82, 'bBzjgTay': 9, 'egQMaRqe': 10, 'vVSuldYi': 12, 'zbYQkDOz': 29, 'gWdjApIt': 48, 'DUBEirbR': 42, 'gEVLdKwA': 33, 'kwBNCAUp': 62, 'cYxJYjPe': 25, 'tLgtoBiM': 14, 'yCFpOpdY': 6, 'DteNqgJD': 29, 'oXzmjPSW': 20, 'XaBJDgIW': 98, 'kshZRZFD': 56, 'MlUbawCs': 43, 'QkguXeuz': 51, 'MIBkvcne': 89, 'xkRbHPVZ': 74, 'JvBOKLxk': 66, 'TloxfXMr': 80, 'KoUNFcHc': 47, 'CwWgxpoE': 3}
# Supplier Reliability: [('mBDYhRUe', 992.95), ('fueIsZkc', 990.85), ('HCXvstLl', 972.4), ('oLIAZrge', 968.13), ('kyavilmB', 959.21), ('SWHzXxPD', 955.29), ('MvtJOGdi', 954.44), ('xEjyDNqh', 951.68), ('GqKIGLAA', 950.49), ('oGoHWqPy', 917.6), ('OjSWxZkP', 907.93), ('EBcWZVEX', 905.0), ('uPBrfTGk', 891.52), ('ZXhHBKop', 869.36), ('oFxYzTQW', 868.18), ('qgIiTrDH', 850.06), ('uuoheTXr', 840.12), ('NGjDaYVZ', 831.62), ('oIxwOrMK', 807.21), ('FuPYBvTP', 801.13), ('xVBbpeqO', 781.76), ('msrZeITP', 772.96), ('UKRIJhuX', 751.1), ('hptsISDN', 750.6), ('fxyBdhfx', 749.1), ('BwpiFPRP', 737.83), ('rwIhCkHV', 733.24), ('KauYdcnH', 727.34), ('XgQVgVhM', 690.24), ('rccRPnLW', 686.26), ('xXsoTdar', 685.7), ('QJybIRve', 683.81), ('gWarQGpU', 677.39), ('EXSvCSjf', 656.21), ('lsqoJfaB', 645.52), ('VTbAhENr', 638.17), ('NUUIkHeO', 612.6), ('BpSUjpVX', 609.09), ('INphtuSR', 598.98), ('lbIyQHlG', 579.23), ('oRBjbfjs', 578.97), ('oNplGQJZ', 577.39), ('CqRIAGAX', 564.19), ('qKmlQjfl', 556.48), ('SuGKLEqb', 554.39), ('IWCMdagu', 553.25), ('YvuVjZTS', 505.8), ('AkeuISed', 485.37), ('WKhRGLBd', 481.76), ('mxIEYanm', 462.38), ('LJhuemeN', 461.41), ('tqbnlxRi', 448.46), ('JLTrRict', 429.94), ('oiTydaWU', 424.69), ('IlAfsaOw', 422.8), ('kbFJZptm', 412.04), ('IIpeZcvf', 401.17), ('gyyNoFOp', 379.32), ('ibBzRKvH', 376.19), ('WbwosCUk', 372.33), ('tGRHwQDg', 371.28), ('hmqBuMxt', 357.17), ('sgYRaUsd', 355.26), ('NEYJEXuO', 353.71), ('mVDuZyxx', 352.63), ('LXZnpOIZ', 351.04), ('ASxvNODQ', 346.32), ('LpeSpdCl', 330.43), ('SzUCaQjS', 330.41), ('CJshkOVJ', 317.43), ('oydwHkto', 315.35), ('QdeHzqWs', 310.23), ('OlzYWvzC', 303.94), ('ydMdYXlZ', 301.14), ('IxgvseUC', 271.78), ('WWfkiorT', 266.45), ('oYTHYjgI', 265.97), ('JDwrxaAD', 263.46), ('FkejbOtI', 257.86), ('fyCYjFNX', 255.88), ('nliFSzin', 239.15), ('pYUPDEOo', 219.99), ('KsTpCCCl', 216.86), ('jYArdIik', 204.44), ('xekDXkqP', 202.88), ('ByRaQhxV', 180.73), ('bwZZSEFG', 172.78), ('fJVRuMDh', 139.46), ('YInIpBcB', 129.31), ('sXRKXSNK', 89.34), ('VHkehmdq', 81.29), ('gofQqFCS', 79.86), ('wDsmrfEo', 71.99), ('rChEXGly', 70.37), ('OHMPdqhW', 35.92), ('fuHchKVj', 31.75), ('QNcmTOWr', 16.82), ('LqjTKKjM', 13.5), ('keRmzshc', 11.9), ('qQpWHRZc', 8.32)]
# Parts Nearing Expiry: ['ygsRsQcu', 'AfsvQsvS', 'uDlTiStl', 'WjTrWyRX', 'nsLgYdJU', 'GPvowryr', 'GzocVWAA', 'umxwvkyh', 'CzRuwvIU', 'FamzNWaJ', 'onLlVkVt', 'rbVlqUAA', 'oMgwwWuK', 'MMHCcxts']
# Average Demand for Product Offerings: 49.666666666666664
# Total Operating Cost of Facilities: 10955.400000000001
# Safety Stock Levels in Warehouses: {'eWchZYRX': 65, 'IiwAGNSn': 77, 'vWCkUCQm': 11, 'yTiAZsDi': 8, 'iNcMvIVA': 81, 'vJpOqyeC': 70, 'wxvqmwqT': 18, 'SWUFfMZs': 74, 'lsXnhHdH': 37, 'pSWYIzXa': 25, 'vgHNfewY': 36, 'JRZvwomO': 9, 'JigUivKh': 77, 'HDKTRhTB': 96, 'EKhUatdS': 40, 'mSojwEoo': 77, 'izkuayyI': 80, 'wwVFELoF': 72, 'CRWsHVzw': 15, 'hFHXNsCU': 46, 'PGfHaPZa': 71, 'LDXFmTRI': 96, 'YVgbJLSQ': 86, 'kgKtWSWC': 67, 'mHyyGadG': 16, 'uGQAiaBo': 92, 'DHyPKhMa': 27, 'VjjATpac': 73, 'QQoxDPdM': 59, 'iOnHNywh': 84, 'gBKpmXxD': 15, 'BPGIWpYC': 44, 'bifliefn': 93, 'aWHmDNrx': 68, 'IxRTeKJB': 88, 'dCIkcCWQ': 99, 'YXarmeNj': 48, 'WRGvDFLP': 82, 'cpyNAMuv': 69, 'GZshKMTK': 68, 'FcqRMWIn': 1, 'PtzHvAAQ': 15, 'eOSUmSxC': 50, 'HshRmseY': 58, 'ptTncHvq': 50, 'FEGGwrsi': 31, 'kXiPYyAv': 55, 'qTMvFCXQ': 53, 'pBLEjLXO': 24, 'mYSfVLit': 100, 'zxXYzuAt': 85, 'HTyXEoAY': 53, 'tBkAvFoZ': 32, 'hrKwABOW': 41, 'PcRPdsku': 31, 'NyPDKpZW': 57, 'raEsSsfI': 79, 'GHRtKwCq': 45, 'JApXpVmN': 27, 'HuVPVSNi': 53, 'HLUdfHgA': 58, 'apVYLvVs': 17, 'etsvDcAY': 50, 'BrNLfQGk': 30, 'vagZOBDr': 61, 'EmptHziW': 39, 'YoDyVGjG': 48, 'cfWBRNMO': 59, 'NSXRZsqG': 72, 'DnOcjrxB': 9, 'YgkiRlJk': 12, 'mFGHLgRV': 41, 'jUTQzrEE': 82, 'RzaZnyYc': 1, 'zKQbUatA': 32, 'iPfMrTIF': 97, 'JmrWHfoM': 59, 'TMHsmiKm': 50, 'eJEJGQWP': 60, 'vbcVzAYh': 55, 'LFBdCwPE': 66, 'ctjZJaan': 43, 'miNQMuUH': 33, 'xTzfppVO': 53, 'YnzkZPGH': 32, 'lHafErqM': 93, 'jmLTUkah': 5, 'KSDuhtOQ': 9, 'wmbwcLom': 46, 'CztccWcP': 21, 'duJxKXHO': 84, 'JpRPIbCV': 70, 'oQqSUiNj': 34, 'rxhabTjS': 81, 'AlwqnFZA': 99, 'GDeVCOAe': 73, 'fqbayTdQ': 49, 'cDpHSwfg': 95, 'kgmWFwHw': 55, 'EQipZnEE': 53}
# Relationship Costs: Transportation - 99362.71000000008, Storage - 100915.54999999994
# Nodes Created After Timestamp: []
# Results for 17.json:
# Revenue by Business Unit: {'YbdbTWFN': 468.51, 'gQxtAGMj': 186.06, 'uhTkgszG': 20.1}
# Total Cost of Product Offerings: 4136.22
 31, 'NyPDKpZW': 57, 'raEsSsfI': 79, 'GHRtKwCq': 45, 'JApXpVmN': 27, 'HuVPVSNi': 53, 'HLUdfHgA': 58, 'apVYLvVs': 17, 'etsvDcAY': 50, 'BrNLfQGk': 30, 'vagZOBDr': 61, 'EmptHziW': 39, 'YoDyVGjG': 48, 'cfWBRNMO': 59, 'NSXRZsqG': 72, 'DnOcjrxB': 9, 'YgkiRlJk': 12, 'mFGHLgRV': 41, 'jUTQzrEE': 82, 'RzaZnyYc': 1, 'zKQbUatA': 32, 'iPfMrTIF': 97, 'JmrWHfoM': 59, 'TMHsmiKm': 50, 'eJEJGQWP': 60, 'vbcVzAYh': 55, 'LFBdCwPE': 66, 'dYQMEYoa': 75, 'miNQMuUH': 33, 'xTzfppVO': 53, 'YnzkZPGH': 32, 'lHafErqM': 93, 'jmLTUkah': 5, 'KSDuhtOQ': 9, 'wmbwcLom': 46, 'CztccWcP': 21, 'duJxKXHO': 84, 'JpRPIbCV': 70, 'oQqSUiNj': 34, 'rxhabTjS': 81, 'AlwqnFZA': 99, 'GDeVCOAe': 73, 'fqbayTdQ': 49, 'cDpHSwfg': 95, 'kgmWFwHw': 55, 'EQipZnEE': 53}
# Relationship Costs: Transportation - 99362.71000000008, Storage - 101192.75999999995
# Nodes Created After Timestamp: []
# Results for 18.json:
# ...
# Relationship Costs: Transportation - 99124.34000000007, Storage - 103307.58999999992
# Nodes Created After Timestamp: []
# Results for 97.json:
# Revenue by Business Unit: {'FVMsvYEd': 572.91, 'PQjRGYqy': 650.59, 'ONtvZsZr': 855.13}
# Total Cost of Product Offerings: 5240.66
# Facility Utilization: {'sZhdRRLd': 47, 'ekiSGtmQ': 37, 'egQMaRqe': 10, 'vVSuldYi': 34, 'JgLGozSU': 29, 'armRIVht': 80, 'yyeGacnC': 36, 'vYiFoBzA': 38, 'qjNSsEAP': 57, 'hGSfGTsT': 83, 'tLgtoBiM': 14, 'MYCPtlqg': 44, 'ARGjWLGx': 85, 'FromWXDH': 20, 'ePOGtkTE': 49, 'ykJNCCAG': 56, 'wStsxzpC': 42, 'QkguXeuz': 12, 'ionnXFHN': 17, 'xkRbHPVZ': 74, 'tIQdVRad': 10, 'XFHaoPDh': 95, 'KoUNFcHc': 36, 'CwWgxpoE': 18}
# Supplier Reliability: [('wdMsPzGo', 996.54), ('mBDYhRUe', 992.95), ('pwHuJJwY', 990.85), ('tibLibUa', 987.69), ('HCXvstLl', 972.4), ('oLIAZrge', 968.13), ('kyavilmB', 959.21), ('MvtJOGdi', 954.44), ('WzugFvRU', 950.49), ('XyEZRglB', 950.33), ('TsHsBzgC', 918.01), ('OjSWxZkP', 907.93), ('EBcWZVEX', 905.0), ('LEmdXuiW', 891.52), ('PsiOpxJP', 853.96), ('qgIiTrDH', 850.06), ('ldtbKJeh', 840.12), ('oIxwOrMK', 807.21), ('wLdQgOBh', 801.13), ('kdTBQESS', 795.36), ('UKRIJhuX', 751.1), ('hptsISDN', 750.6), ('fxyBdhfx', 749.1), ('BwpiFPRP', 737.83), ('KauYdcnH', 727.34), ('XgQVgVhM', 690.24), ('rccRPnLW', 686.26), ('xXsoTdar', 685.7), ('gWarQGpU', 677.39), ('EXSvCSjf', 656.21), ('oGoHWqPy', 651.65), ('lsqoJfaB', 645.52), ('uJxJXQns', 640.64), ('NUUIkHeO', 612.6), ('CURhMGpo', 609.09), ('INphtuSR', 598.98), ('lbIyQHlG', 579.23), ('oNplGQJZ', 577.39), ('ZXhHBKop', 576.39), ('iWVoPsBK', 564.19), ('rChEXGly', 562.89), ('BLtYUUju', 559.0), ('qKmlQjfl', 556.48), ('pKVgokqf', 553.25), ('QdeHzqWs', 507.79), ('oRBjbfjs', 491.41), ('FvrNzYwc', 485.37), ('WKhRGLBd', 481.76), ('EEErzdnp', 462.38), ('QNcmTOWr', 460.72), ('XimxrBvK', 448.46), ('JLTrRict', 429.94), ('IlAfsaOw', 422.8), ('YInIpBcB', 421.52), ('ttHkVlNv', 412.04), ('zMcLfxzc', 401.17), ('QaLQvthW', 379.32), ('ibBzRKvH', 376.19), ('ASxvNODQ', 374.45), ('WbwosCUk', 372.33), ('tGRHwQDg', 371.28), ('hmqBuMxt', 357.17), ('sgYRaUsd', 355.26), ('NEYJEXuO', 353.71), ('mVDuZyxx', 352.63), ('SzUCaQjS', 330.41), ('CJshkOVJ', 317.43), ('XboWHhGH', 315.35), ('OlzYWvzC', 303.94), ('ydMdYXlZ', 301.14), ('xekDXkqP', 288.58), ('IxgvseUC', 271.78), ('WWfkiorT', 266.45), ('UBVZoSFF', 265.97), ('IaUOKqra', 265.93), ('JDwrxaAD', 263.46), ('FkejbOtI', 257.86), ('fyCYjFNX', 255.88), ('oiTydaWU', 254.83), ('nliFSzin', 239.15), ('zOyGJWWt', 237.84), ('pYUPDEOo', 219.99), ('jgoiHnEt', 209.33), ('NGjDaYVZ', 193.66), ('ByRaQhxV', 180.73), ('xVBbpeqO', 161.78), ('fJVRuMDh', 139.46), ('LXZnpOIZ', 125.62), ('fzCslkMf', 104.01), ('VHkehmdq', 81.29), ('gofQqFCS', 79.86), ('wDsmrfEo', 71.99), ('JhXnFNOM', 64.91), ('dHnhtcbl', 60.35), ('jYArdIik', 45.53), ('OHMPdqhW', 35.92), ('fuHchKVj', 31.75), ('LqjTKKjM', 13.5), ('keRmzshc', 11.9), ('qQpWHRZc', 8.32)]
# Parts Nearing Expiry: ['ygsRsQcu', 'uDlTiStl', 'WjTrWyRX', 'RHkJiQUn', 'EmsXEQOs', 'GzocVWAA', 'ByVvXOym', 'umxwvkyh', 'kMEKiNsb', 'wsbZORtO', 'pWlWfuAt']
# Average Demand for Product Offerings: 53.166666666666664
# Total Operating Cost of Facilities: 12422.230000000001
# Safety Stock Levels in Warehouses: {'eWchZYRX': 65, 'nluhoZdu': 77, 'vWCkUCQm': 11, 'yTiAZsDi': 16, 'iNcMvIVA': 81, 'vJpOqyeC': 70, 'DVfHDlMR': 9, 'SWUFfMZs': 74, 'lsXnhHdH': 37, 'pnSNuMeB': 25, 'vgHNfewY': 36, 'JRZvwomO': 9, 'JigUivKh': 77, 'HDKTRhTB': 96, 'EKhUatdS': 40, 'mSojwEoo': 19, 'NeJPTjwN': 80, 'pliEyEhh': 72, 'CRWsHVzw': 15, 'hFHXNsCU': 46, 'PGfHaPZa': 71, 'LDXFmTRI': 96, 'YVgbJLSQ': 86, 'kgKtWSWC': 67, 'mHyyGadG': 16, 'uGQAiaBo': 92, 'DHyPKhMa': 27, 'VjjATpac': 73, 'QQoxDPdM': 84, 'iOnHNywh': 44, 'gBKpmXxD': 15, 'BPGIWpYC': 44, 'FojiaqBS': 56, 'UkchKLSz': 68, 'IxRTeKJB': 88, 'dCIkcCWQ': 99, 'YXarmeNj': 48, 'ARdZDKGE': 82, 'HngpzLVj': 69, 'AdvEmBnJ': 68, 'FcqRMWIn': 1, 'XBIlHvoW': 15, 'iVlGyuMr': 50, 'HshRmseY': 58, 'ptTncHvq': 50, 'ozTOGmgV': 31, 'kXiPYyAv': 55, 'qTMvFCXQ': 53, 'pBLEjLXO': 24, 'mYSfVLit': 100, 'qWpWSvGM': 86, 'HTyXEoAY': 53, 'tBkAvFoZ': 32, 'hrKwABOW': 41, 'XRCqzEjv': 31, 'NyPDKpZW': 57, 'raEsSsfI': 79, 'GHRtKwCq': 95, 'ECSxaxOI': 27, 'HuVPVSNi': 53, 'HLUdfHgA': 58, 'NZidaBka': 17, 'yVFqIkqS': 50, 'BrNLfQGk': 30, 'vagZOBDr': 61, 'EmptHziW': 39, 'YoDyVGjG': 48, 'cfWBRNMO': 59, 'NSXRZsqG': 72, 'DnOcjrxB': 9, 'eehHOsJT': 33, 'mFGHLgRV': 41, 'jUTQzrEE': 82, 'RzaZnyYc': 1, 'oWdonsOG': 32, 'riaSdsfk': 97, 'JmrWHfoM': 59, 'hVEFqOfw': 50, 'eJEJGQWP': 60, 'vbcVzAYh': 55, 'uJglPxYb': 56, 'sLzfEGib': 78, 'miNQMuUH': 33, 'YwPYkrXb': 53, 'YnzkZPGH': 1, 'lHafErqM': 93, 'jmLTUkah': 5, 'KSDuhtOQ': 9, 'UZdKqPlG': 46, 'CztccWcP': 21, 'VOXhvrPr': 84, 'uOyiSmZa': 60, 'oQqSUiNj': 34, 'rxhabTjS': 81, 'AlwqnFZA': 99, 'KLrNwkkM': 55, 'CfaMuDqU': 29, 'WGSNNlnp': 95, 'kgmWFwHw': 55, 'EQipZnEE': 92}
# Relationship Costs: Transportation - 99124.34000000007, Storage - 103307.58999999992
# Nodes Created After Timestamp: []
# Results for 98.json:
# Revenue by Business Unit: {'FVMsvYEd': 572.91, 'PQjRGYqy': 650.59, 'ONtvZsZr': 855.13}
# Total Cost of Product Offerings: 5528.92
# Facility Utilization: {'sZhdRRLd': 47, 'ekiSGtmQ': 37, 'egQMaRqe': 10, 'vVSuldYi': 34, 'JgLGozSU': 29, 'armRIVht': 80, 'yyeGacnC': 36, 'vYiFoBzA': 38, 'qjNSsEAP': 57, 'hGSfGTsT': 83, 'tLgtoBiM': 14, 'MYCPtlqg': 44, 'ARGjWLGx': 85, 'FromWXDH': 20, 'ePOGtkTE': 49, 'ykJNCCAG': 56, 'wStsxzpC': 42, 'QkguXeuz': 12, 'ionnXFHN': 17, 'xkRbHPVZ': 74, 'tIQdVRad': 10, 'XFHaoPDh': 95, 'KoUNFcHc': 36, 'CwWgxpoE': 18}
# Supplier Reliability: [('wdMsPzGo', 996.54), ('mBDYhRUe', 992.95), ('pwHuJJwY', 990.85), ('tibLibUa', 987.69), ('HCXvstLl', 972.4), ('oLIAZrge', 968.13), ('kyavilmB', 959.21), ('MvtJOGdi', 954.44), ('WzugFvRU', 950.49), ('XyEZRglB', 950.33), ('TsHsBzgC', 918.01), ('OjSWxZkP', 907.93), ('EBcWZVEX', 905.0), 
 'oQqSUiNj': 34, 'rxhabTjS': 81, 'AlwqnFZA': 99, 'KLrNwkkM': 55, 'CfaMuDqU': 29, 'WGSNNlnp': 95, 'kgmWFwHw': 55, 'EQipZnEE': 92}
# Relationship Costs: Transportation - 99124.34000000007, Storage - 104058.93999999993
# Nodes Created After Timestamp: []
# Results for 99.json:
# Revenue by Business Unit: {'FVMsvYEd': 572.91, 'PQjRGYqy': 650.59, 'ONtvZsZr': 855.13}
# Total Cost of Product Offerings: 5528.92
# Facility Utilization: {'sZhdRRLd': 47, 'ekiSGtmQ': 37, 'egQMaRqe': 10, 'vVSuldYi': 34, 'JgLGozSU': 29, 'armRIVht': 80, 'yyeGacnC': 36, 'vYiFoBzA': 38, 'qjNSsEAP': 57, 'hGSfGTsT': 83, 'LHDytorp': 14, 'MYCPtlqg': 44, 'ARGjWLGx': 85, 'FromWXDH': 20, 'ePOGtkTE': 49, 'ykJNCCAG': 56, 'wStsxzpC': 27, 'QkguXeuz': 12, 'ionnXFHN': 17, 'xkRbHPVZ': 74, 'tIQdVRad': 10, 'XFHaoPDh': 95, 'KoUNFcHc': 36, 'CwWgxpoE': 18}
# Supplier Reliability: [('wdMsPzGo', 996.54), ('mBDYhRUe', 992.95), ('pwHuJJwY', 990.85), ('tibLibUa', 987.69), ('HCXvstLl', 972.4), ('PRPdNOiI', 968.13), ('kyavilmB', 959.21), ('MvtJOGdi', 954.44), ('WzugFvRU', 950.49), ('XyEZRglB', 950.33), ('TsHsBzgC', 918.01), ('OjSWxZkP', 907.93), ('EBcWZVEX', 905.0), ('LEmdXuiW', 891.52), ('PsiOpxJP', 853.96), ('qgIiTrDH', 850.06), ('ldtbKJeh', 840.12), ('oIxwOrMK', 807.21), ('wLdQgOBh', 801.13), ('kdTBQESS', 795.36), ('UKRIJhuX', 751.1), ('hptsISDN', 750.6), ('fxyBdhfx', 749.1), ('BwpiFPRP', 737.83), ('KauYdcnH', 727.34), ('XgQVgVhM', 690.24), ('rccRPnLW', 686.26), ('xXsoTdar', 685.7), ('gWarQGpU', 677.39), ('EXSvCSjf', 656.21), ('oGoHWqPy', 651.65), ('lsqoJfaB', 645.52), ('uJxJXQns', 640.64), ('NUUIkHeO', 612.6), ('CURhMGpo', 609.09), ('INphtuSR', 598.98), ('lbIyQHlG', 579.23), ('oNplGQJZ', 577.39), ('ZXhHBKop', 576.39), ('iWVoPsBK', 564.19), ('rChEXGly', 562.89), ('BLtYUUju', 559.0), ('qKmlQjfl', 556.48), ('pKVgokqf', 553.25), ('QdeHzqWs', 507.79), ('oRBjbfjs', 491.41), ('FvrNzYwc', 485.37), ('WKhRGLBd', 481.76), ('EEErzdnp', 462.38), ('QNcmTOWr', 460.72), ('XimxrBvK', 448.46), ('JLTrRict', 429.94), ('IlAfsaOw', 422.8), ('YInIpBcB', 421.52), ('ttHkVlNv', 412.04), ('zMcLfxzc', 401.17), ('QaLQvthW', 379.32), ('ibBzRKvH', 376.19), ('ASxvNODQ', 374.45), ('WbwosCUk', 372.33), ('tGRHwQDg', 371.28), ('hmqBuMxt', 357.17), ('sgYRaUsd', 355.26), ('
': 57, 'raEsSsfI': 79, 'GHRtKwCq': 95, 'ECSxaxOI': 27, 'HuVPVSNi': 53, 'HLUdfHgA': 58, 'NZidaBka': 17, 'yVFqIkqS': 50, 'BrNLfQGk': 30, 'vagZOBDr': 61, 'EmptHziW': 39, 'YoDyVGjG': 48, 'cfWBRNMO': 59, 'NSXRZsqG': 72, 'DnOcjrxB': 9, 'eehHOsJT': 33, 'mFGHLgRV': 41, 'jUTQzrEE': 82, 'RzaZnyYc': 1, 'oWdonsOG': 32, 'riaSdsfk': 97, 'JmrWHfoM': 59, 'hVEFqOfw': 50, 'eJEJGQWP': 60, 'vbcVzAYh': 55, 'uJglPxYb': 56, 'sLzfEGib': 78, 'miNQMuUH': 33, 'YwPYkrXb': 53, 'YnzkZPGH': 1, 'lHafErqM': 93, 'jmLTUkah': 5, 'KSDuhtOQ': 9, 'UZdKqPlG': 46, 'CztccWcP': 21, 'VOXhvrPr': 84, 'uOyiSmZa': 60, 'oQqSUiNj': 34, 'rxhabTjS': 81, 'AlwqnFZA': 99, 'KLrNwkkM': 55, 'CfaMuDqU': 29, 'WGSNNlnp': 95, 'kgmWFwHw': 55, 'EQipZnEE': 92}
# Relationship Costs: Transportation - 99408.44000000006, Storage - 104058.93999999993
# Nodes Created After Timestamp: []
# Time taken: 0.5574097633361816 seconds
# Memory used: 45.828125 MB

# %%
import json
import os
from functools import lru_cache
from datetime import datetime, timedelta
import psutil
import time

def memory_usage():
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / (1024 ** 2)  # bytes to MB conversion

start_time = time.time()
start_memory = memory_usage()
def aggregate_total_revenue_by_business_unit(folder_path):
    aggregated_revenue = {}
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.json'):
            file_path = os.path.join(folder_path, file_name)
            data = load_json_file(file_path)
            revenue_by_unit = total_revenue_by_business_unit(data)
            for unit, revenue in revenue_by_unit.items():
                if unit in aggregated_revenue:
                    aggregated_revenue[unit] += revenue
                else:
                    aggregated_revenue[unit] = revenue
    return aggregated_revenue

# Example usage
folder_path ='C:/Users/HP/LAM_VS/query_stress/dc_stat_100_large'
aggregated_revenue = aggregate_total_revenue_by_business_unit(folder_path)
print(f"Aggregated Revenue by Business Unit: {aggregated_revenue}")
end_time = time.time()
end_memory = memory_usage()

print(f"Time taken: {end_time - start_time} seconds")
print(f"Memory used: {end_memory - start_memory} MB")
# Out:
# Aggregated Revenue by Business Unit: {'cGeOyTgI': 2342.55, 'RVVIAToD': 784.19, 'hZMPzrIA': 3107.2800000000007, 'YbdbTWFN': 6090.630000000002, 'CrkocJcW': 1674.5399999999997, 'uhTkgszG': 220.14, 'FVMsvYEd': 6874.919999999999, 'PQjRGYqy': 5204.72, 'ONtvZsZr': 5985.91, 'gQxtAGMj': 1488.4799999999998, 'mGuHAYnF': 779.5199999999999, 'ElzOMWCd': 937.02, 'CTJfAEvP': 696.0600000000001, 'YdoWkWBM': 7106.000000000001, 'PsUZKYSj': 3072.9699999999993, 'ApuNEUEM': 5306.7, 'hHikwrTr': 337.84, 'eEBXzYWP': 6731.65, 'KOCESICX': 971.85, 'eidnFfiz': 128.9, 'jsGosjbx': 11374.000000000004, 'WmeXTEQV': 44.26, 'jsXcWnlg': 1441.78, 'JsDUPLgC': 119.67, 'gRufzIQA': 659.64, 'AUpVTNGs': 3378.5, 'MNCnkhdZ': 1309.0, 'JnMJKLPx': 822.04, 'VSyZxTaT': 2020.8999999999994, 'yYxtoNqH': 1644.08, 'eyDMMfWA': 4279.360000000001, 'YssHaaNe': 822.04, 'zJeVgOOi': 3958.8999999999996, 'noEDwHUW': 3591.36, 'etsVsiGj': 801.52, 'mwdKltLH': 401.04, 'tYTeoUZp': 8684.8, 'fpisDDaK': 6505.900000000001, 'iAOoHElv': 500.95, 'fSYKqczG': 884.49, 'ysvFmJzO': 650.59, 'SHoLwCee': 1126.84, 'qcXJSldB': 7156.490000000001, 'eWqxRXNl': 3380.52, 'iujZQpuU': 69.66, 'aVDFmaaH': 23.22, 'rustBMLr': 23.22, 'mtaJwRne': 23.22, 'hkgrMtAB': 5985.91, 'dXmYyXxw': 572.91, 'VVoAIgte': 1301.18}
# Time taken: 0.006351947784423828 seconds
# Memory used: 0.0 MB

# %%
def aggregate_facility_utilization(folder_path):
    total_utilization = 0
    count = 0
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.json'):
            file_path = os.path.join(folder_path, file_name)
            data = load_json_file(file_path)
            utilization = facility_utilization(data)
            total_utilization += sum(utilization.values())
            count += len(utilization)
    return total_utilization / count if count > 0 else 0

# Example usage
average_utilization = aggregate_facility_utilization(folder_path)
print(f"Average Facility Utilization: {average_utilization}%")

# %%
def aggregate_parts_nearing_expiry(folder_path, threshold):
    total_parts_near_expiry = 0
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.json'):
            file_path = os.path.join(folder_path, file_name)
            data = load_json_file(file_path)
            parts_near_expiry = parts_nearing_expiry(data, threshold)
            total_parts_near_expiry += len(parts_near_expiry)
    return total_parts_near_expiry

# Example usage
threshold = 30  # Example threshold for expiry
total_parts_expiry = aggregate_parts_nearing_expiry(folder_path, threshold)
print(f"Total Parts Nearing Expiry: {total_parts_expiry}")

# %%
def aggregate_average_demand_for_product_offerings(folder_path):
    total_demand = 0
    count = 0
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.json'):
            file_path = os.path.join(folder_path, file_name)
            data = load_json_file(file_path)
            total_demand += sum(node['demand'] for node in data['nodes'] if node['node_type'] == 'ProductOffering')
            count += sum(1 for node in data['nodes'] if node['node_type'] == 'ProductOffering')
    return total_demand / count if count > 0 else 0

# Example usage
average_demand = aggregate_average_demand_for_product_offerings(folder_path)
print(f"Overall Average Demand for Product Offerings: {average_demand}")

end_time = time.time()
end_memory = memory_usage()

print(f"Time taken: {end_time - start_time} seconds")
print(f"Memory used: {end_memory - start_memory} MB")

# %%
def aggregate_total_operating_cost_of_facilities(folder_path):
    total_cost = 0
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.json'):
            file_path = os.path.join(folder_path, file_name)
            data = load_json_file(file_path)
            total_cost += total_operating_cost_of_facilities(data)
    return total_cost

# Example usage
aggregated_operating_cost = aggregate_total_operating_cost_of_facilities(folder_path)
print(f"Aggregated Total Operating Cost of Facilities: {aggregated_operating_cost}")

# %%
def aggregate_relationship_costs(folder_path):
    total_transportation_cost = 0
    total_storage_cost = 0
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.json'):
            file_path = os.path.join(folder_path, file_name)
            data = load_json_file(file_path)
            transport_cost, storage_cost = relationship_costs(data)
            total_transportation_cost += transport_cost
            total_storage_cost += storage_cost
    return total_transportation_cost, total_storage_cost

# Example usage
aggregated_transport_cost, aggregated_storage_cost = aggregate_relationship_costs(folder_path)
print(f"Aggregated Transportation Cost: {aggregated_transport_cost}")
print(f"Aggregated Storage Cost: {aggregated_storage_cost}")
